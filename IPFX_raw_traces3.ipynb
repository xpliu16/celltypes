# %%
# from ipfx.sweep import Sweep, SweepSet

# %%
import numpy as np
from matplotlib import pyplot as plt
from ipfx.dataset.create import create_ephys_data_set

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod1/Ephys_Roi_Result_1084277304/Q21.26.006.14.01.03.nwb"         # PVALB high rheobase
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod0/Ephys_Roi_Result_998543710/nwb2_Q20.26.001.11.03.03.nwb"    # PVALB no complete long trace set
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod46/Ephys_Roi_Result_1173272167/QN22.26.016.14.02A.03.nwb"    # CCK-VIP-TAC3 - used
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.016.14.02A.03.nwb"     # CCK-VIP-TAC3, same as above
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN21.26.028.14.53.04.nwb"  # PVALB - used
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod68/Ephys_Roi_Result_1287023589/QN23.26.016.14.06A.06.nwb"
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN23.26.016.14.06A.06.nwb"   # CHAT
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod8/Ephys_Roi_Result_1116575361/Q21.26.023.13.04.03.nwb"
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/Q21.26.023.13.04.03.nwb"    # SST-Chodl
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/Q21.26.013.12.02.01.nwb"    # SST-Chodl
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod70/Ephys_Roi_Result_1182683972/QN22.26.020.14.03.01.nwb"
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.020.14.03.01.nwb"    # CCK-FBXL7
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod11/Ephys_Roi_Result_1160525223/QM22.26.003.14.51.03.nwb" 
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QM22.26.003.14.51.03.nwb"   # LHX6-TAC3-PLPP4  Used although doesn't go very negative
#nwb_path =  "/allen/programs/celltypes/production/humancelltypes/prod11/Ephys_Roi_Result_1167375001/QN22.26.010.14.51.02.nwb"
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.010.14.51.02.nwb"    # LHX6-TAC3-PLPP4
#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod46/Ephys_Roi_Result_1170462060/QN22.26.014.14.3A.01.nwb"
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.014.14.3A.01.nwb" # LHX6-TAC3-PLPP4  no good

#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.016.14.03A.04.nwb"    # For testing a cell with chirp pass

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod104/Ephys_Roi_Result_1199233032/QN22.26.030.14.07A.02.nwb"   # Cell with CHIRPA but Failed Chirp QM22.26.030.14.07A.03
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.030.14.07A.02.nwb"

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod121/Ephys_Roi_Result_1223237942/QN22.26.036.14.07B.03.nwb"   # High sync freq chirp, sweeps 55,56,57
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.036.14.07B.03.nwb"

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod68/Ephys_Roi_Result_1287544772/QN23.26.016.14.07B.01.nwb"   # High sync freq chirp, sweeps 54 through 59
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN23.26.016.14.07B.01.nwb"

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod46/Ephys_Roi_Result_1170583480/QN22.26.014.14.5B.02.nwb"   # High sync freq chirp, sweeps 54-72
#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.014.14.5B.02.nwb"    

#nwb_path = "/allen/programs/celltypes/production/humancelltypes/prod11/Ephys_Roi_Result_1166306608/QN22.26.010.14.54.04.nwb"   # For testing a cell with chirp pass

#nwb_path = "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.023.14.51A.01.nwb"     # CHAT cell attached, sweep 6

nwb_path =  "/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/nwb/QN22.26.037.14.06A.01.nwb"

plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

dataset = create_ephys_data_set(nwb_file=nwb_path)
long_squares = dataset.filtered_sweep_table(stimuli=dataset.ontology.long_square_names) # more on this next!
sweep_set = dataset.sweep_set(long_squares.sweep_number)
# Out:
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/hdmf/spec/namespace.py:532: UserWarning: Ignoring cached namespace 'hdmf-common' version 1.1.3 because version 1.5.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/hdmf/spec/namespace.py:532: UserWarning: Ignoring cached namespace 'core' version 2.2.4 because version 2.3.0 is already loaded.
#   warn("Ignoring cached namespace '%s' version %s because version %s is already loaded."
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/ipfx/stimulus.py:146: UserWarning: Could not find stimulus: X0NRMP
#   warnings.warn("Could not find stimulus: %s" % tag)
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/ipfx/stimulus.py:146: UserWarning: Could not find stimulus: X7RAMP
#   warnings.warn("Could not find stimulus: %s" % tag)
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/ipfx/stimulus.py:146: UserWarning: Could not find stimulus: X0NRMP
#   warnings.warn("Could not find stimulus: %s" % tag)
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/ipfx/stimulus.py:146: UserWarning: Could not find stimulus: X7RAMP
#   warnings.warn("Could not find stimulus: %s" % tag)

# %%
#import numpy as np
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#sweep = dataset.sweep(sweep_number)
sweep_list = [10, 11, 19, 20, 22, 24, 32]   # CCK-VIP-TAC3
sweep_rheo = 32

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.3, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))
print(round(np.min(all_i)))
print(round(np.max(all_i)))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.63
x_max_ap = x_min_ap +0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

#axs[2].set_xlim([0.63, 0.655])
#axs[2].plot([0.65, 0.653], [-40, -40], 'k', linewidth = 4)    # 3 ms

axs[1].text(1.1, max_i + 28, str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.1, min_i - 28, str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

#plt.savefig('/home/xiaoping.liu/raw_trace/CCK-VIP-TAC3_QN22260161402A03.png')
#plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN22260161402A03_CCK-VIP-TAC3.png')
plt.show()
# Out:
# -42
# 370
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_13282/305727253.py:37: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_13282/305727253.py:38: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# NOT USED PVALB CELL

#import numpy as np
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

#sweep = dataset.sweep(sweep_number)
#sweep_list = [5, 6, 7, 8, 9, 16, 17, 18, 19, 20]   # PVALB    #16 maybe
sweep_list = [5, 6, 7, 8, 9, 17, 20]  
sweep_rheo = 17

fig,axs = plt.subplots(3,1, figsize = (5,9), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        tr_color = 'crimson'
    else:
        tr_color = 'darkblue'
    axs[0].plot(t,v,tr_color)
    axs[0].axis('off')

    axs[1].plot(t,i,tr_color)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))
print(round(np.min(all_i)))
print(round(np.max(all_i)))

plt.xlim([0.5, 2.0])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
axs[2].set_xlim([0.63, 0.655])     # 25 ms
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.65, 0.653], [-40, -40], 'k', linewidth = 4)    # 3 ms

axs[1].text(1.1, max_i + 21, str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.1, min_i - 23, str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

#plt.savefig('/home/xiaoping.liu/raw_trace/CCK-VIP-TAC3_QN22260161402A03.png')
plt.show()
# Out:
# -70
# 10
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/378622430.py:40: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/378622430.py:41: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
#sweep = dataset.sweep(sweep_number)
sweep_list = [4,5,6,8,9,10,20,18]   # PVALB  QN21.26.028.14.53.04.nwb   
sweep_rheo = 18

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))
print(round(np.min(all_i)))
print(round(np.max(all_i)))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 1.197
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

axs[1].text(1.1, max_i + 40, str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.1, min_i - 40, str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN2126028145304_PVALB.png')
plt.show()
# Out:
# -110
# 72
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/3772077855.py:32: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/3772077855.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
#sweep_list = [11,12,13,14,]   # CHAT    14 or 17, 22, 23
sweep_list = [43, 45, 47, 48, 88, 93]
sweep_rheo = 93
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.88
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
#axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
#axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.1, max_i + 0.3*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.1, min_i - 0.35*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN23260161406A06_CHAT.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/2434050590.py:32: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/2434050590.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# SST-Chodl

#sweep_list = [6, 8, 14, 16, 18, 48]
sweep_list = [29, 35, 36, 41, 48, 66, 64]
sweep_rheo = 64
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 1.03
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.1, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.1, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/Q2126023130403_SST-Chodl.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_95577/2708058476.py:35: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_95577/2708058476.py:36: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# For CHAT cell attached spont

sweep_list = [6]

sweep_rheo = 64
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,14), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
#fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.8, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=1)   # was 2
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=1)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

axs[0].set_xlim([45, 53])
axs[1].set_ylim([-120, 50])

axs[1].plot([50, 52], [-120, -120], 'k', linewidth = 7)     # 2 s
axs[0].set_xlim([45, 53])
axs[1].set_ylim([-120, 50])

#plt.xlim([0.5, 2.0])
#axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 1.03
x_max_ap = x_min_ap+0.04
#axs[2].set_xlim([x_min_ap, x_max_ap])
#axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

#yl = axs[2].get_ylim()
#axs[1].text(1.1, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
#axs[1].text(1.1, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

#plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/Q2126013120201_SST-Chodl.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_55642/1211728822.py:42: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_55642/1211728822.py:43: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# For chodl spont

sweep_list = [6]

sweep_rheo = 64
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,14), sharex = True, gridspec_kw={'height_ratios': [0.2, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=1)   # was 2
    #axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=1)
    #axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 1.03
x_max_ap = x_min_ap+0.04
#axs[2].set_xlim([x_min_ap, x_max_ap])
# For Chodl spont
axs[0].plot([6.5, 7.5], [-40, -40], 'k', linewidth = 2.5)     # 1 s
axs[0].plot([6.5, 6.5], [-20, -40], 'k', linewidth = 2.5)      # 20 mV
#axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

#yl = axs[2].get_ylim()
#axs[1].text(1.1, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
#axs[1].text(1.1, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

#plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/Q2126013120201_SST-Chodl.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_71404/4038821064.py:32: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_71404/4038821064.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# Test viewer

sweep_list = [6]

sweep_rheo = 64
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,14), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
#fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.8, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=1)   # was 2
    #axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=1)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

#axs[0].set_xlim([45, 53])
#axs[1].set_ylim([-120, 50])

# For cell attached
#axs[1].plot([50, 52], [-120, -120], 'k', linewidth = 7)     # 2 s
#axs[0].set_xlim([45, 53])
#axs[1].set_ylim([-120, 50])

#plt.xlim([0.5, 2.0])
#axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 1.03
x_max_ap = x_min_ap+0.04
#axs[2].set_xlim([x_min_ap, x_max_ap])
# For Chodl spont
axs[0].plot([6.5, 7.5], [-40, -40], 'k', linewidth = 4)     # 1 s
axs[0].plot([6.5, 6.5], [-20, -40], 'k', linewidth = 4)      # 20 mV
#axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

#yl = axs[2].get_ylim()
#axs[1].text(1.1, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
#axs[1].text(1.1, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

#plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/Q2126013120201_SST-Chodl.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_55642/2955329521.py:43: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_55642/2955329521.py:44: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# CCK-FBXL7

sweep_list = [5,6,7,8,9,18,15]
sweep_rheo = 15
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.61
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.05, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.05, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN2226020140301_CCK-FBXL7.png')
plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/3890111150.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/3890111150.py:34: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# TAC3-PLPP4

sweep_list = [4,22,23,45,43]
sweep_rheo = 43
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.75
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-30, -30], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.05, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.05, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QM2226003145103_LHX6-TAC3-PLPP4.png')

plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/235032707.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/235032707.py:34: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# TAC3-PLPP4    Second option

sweep_list = [16,32,33]
sweep_rheo = 43
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.61
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.05, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.05, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN2226010145102_LHX6-TAC3-PLPP4.png')

plt.show()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/895925925.py:33: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[0])
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_99305/895925925.py:34: MatplotlibDeprecationWarning: The remove function was deprecated in Matplotlib 3.6 and will be removed two minor releases later.
#   g.remove(axs[1])

# %%
# TAC3-PLPP4

sweep_list = [16,32,33]
sweep_rheo = 43
plt.rcParams['figure.dpi'] = 600
plt.rcParams['savefig.dpi'] = 600

fig,axs = plt.subplots(3,1, figsize = (5,10), sharex = True, gridspec_kw={'height_ratios': [1, 0.25, 0.7]})
all_i = np.array([])
for sw in sweep_list:
    sweep = dataset.sweep(sw)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    if (sw == sweep_rheo):
        color = 'crimson'
    else:
        color = 'darkblue'
    axs[0].plot(t,v,color,linewidth=2)
    axs[0].axis('off')
    axs[1].plot(t,i,color,linewidth=2)
    axs[1].axis('off')
    if (sw == sweep_rheo):
        axs[2].plot(t,v, 'crimson')
        axs[2].axis('off')
    all_i = np.concatenate((all_i, np.squeeze(sweep.i)))
min_i = round(np.min(all_i))
max_i = round(np.max(all_i))

plt.xlim([0.5, 2.0])
axs[0].set_ylim([-120, 50])
g = axs[2].get_shared_x_axes()
g.remove(axs[0])
g.remove(axs[1])
x_min_ap = 0.61
x_max_ap = x_min_ap+0.04
axs[2].set_xlim([x_min_ap, x_max_ap])
axs[0].plot([1.8, 2.0], [-40, -40], 'k', linewidth = 4)     # 200 ms
axs[0].plot([1.8, 1.8], [-20, -40], 'k', linewidth = 4)      # 20 mV
axs[2].plot([0.7*(x_max_ap-x_min_ap)+x_min_ap, 0.7*(x_max_ap-x_min_ap)+x_min_ap + 0.003], [-40, -40], 'k', linewidth = 4)    # 3 ms

yl = axs[2].get_ylim()
axs[1].text(1.05, max_i + 0.35*(yl[1]-yl[0]), str(max_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')
axs[1].text(1.05, min_i - 0.4*(yl[1]-yl[0]), str(min_i) + ' pA', size = 18, color = 'k', horizontalalignment = 'center', verticalalignment = 'center')

plt.savefig('/Users/xiaoping.liu/celltypes/NHP_BG_anal/raw_traces/python/QN2226014143A01_LHX6-TAC3-PLPP4.png')

plt.show()

# %%
long_squares = dataset.filtered_sweep_table(stimuli=dataset.ontology.long_square_names) # more on this next!
#sweep_set = dataset.sweep_set(long_squares.sweep_number
long_squares.sweep_number
#long_squares.columns
long_squares
# Out:
#     sweep_number stimulus_units  bridge_balance_mohm    leak_pa  \
# 4              4           Amps              9.70696        NaN
# 5              5           Amps              9.70696        NaN
# 6              6           Amps              9.70696        NaN
# 7              7           Amps              9.70696        NaN
# 8              8           Amps              9.70696        NaN
# 18            18           Amps              9.70696        NaN
# 19            19           Amps              9.70696   4.115226
# 20            20           Amps              9.70696   4.115226
# 21            21           Amps              9.70696   4.115226
# 22            22           Amps              9.70696   4.115226
# 23            23           Amps              9.70696   4.115226
# 24            24           Amps              9.70696   4.115226
# 25            25           Amps              9.70696   4.115226
# 26            26           Amps              9.70696  18.106995
# 27            27           Amps              9.70696  18.106995
# 28            28           Amps              9.70696  18.106995
# 29            29           Amps              9.70696  25.324471
#
#     capacitance_compensation  sampling_rate  stimulus_scale_factor  \
# 4                        0.0        50000.0                   10.0
# 5                        0.0        50000.0                   10.0
# 6                        0.0        50000.0                   10.0
# 7                        0.0        50000.0                   10.0
# 8                        0.0        50000.0                   10.0
# 18                       0.0        50000.0                   10.0
# 19                       0.0        50000.0                   10.0
# 20                       0.0        50000.0                   10.0
# 21                       0.0        50000.0                   10.0
# 22                       0.0        50000.0                   10.0
# 23                       0.0        50000.0                   10.0
# 24                       0.0        50000.0                   10.0
# 25                       0.0        50000.0                   10.0
# 26                       0.0        50000.0                   10.0
# 27                       0.0        50000.0                   10.0
# 28                       0.0        50000.0                   10.0
# 29                       0.0        50000.0                   10.0
#
#        stimulus_code    stimulus_code_ext    clamp_mode stimulus_name
# 4     X1PS_SubThresh    X1PS_SubThresh[0]  CurrentClamp   Long Square
# 5     X1PS_SubThresh    X1PS_SubThresh[1]  CurrentClamp   Long Square
# 6     X1PS_SubThresh    X1PS_SubThresh[2]  CurrentClamp   Long Square
# 7     X1PS_SubThresh    X1PS_SubThresh[3]  CurrentClamp   Long Square
# 8     X1PS_SubThresh    X1PS_SubThresh[4]  CurrentClamp   Long Square
# 18         X3LP_Rheo         X3LP_Rheo[0]  CurrentClamp   Long Square
# 19         X3LP_Rheo         X3LP_Rheo[1]  CurrentClamp   Long Square
# 20  X4PS_SupraThresh  X4PS_SupraThresh[0]  CurrentClamp   Long Square
# 21  X4PS_SupraThresh  X4PS_SupraThresh[1]  CurrentClamp   Long Square
# 22  X4PS_SupraThresh  X4PS_SupraThresh[2]  CurrentClamp   Long Square
# 23  X4PS_SupraThresh  X4PS_SupraThresh[3]  CurrentClamp   Long Square
# 24  X4PS_SupraThresh  X4PS_SupraThresh[4]  CurrentClamp   Long Square
# 25  X4PS_SupraThresh  X4PS_SupraThresh[5]  CurrentClamp   Long Square
# 26  X4PS_SupraThresh  X4PS_SupraThresh[6]  CurrentClamp   Long Square
# 27  X4PS_SupraThresh  X4PS_SupraThresh[7]  CurrentClamp   Long Square
# 28  X4PS_SupraThresh  X4PS_SupraThresh[8]  CurrentClamp   Long Square
# 29  X4PS_SupraThresh  X4PS_SupraThresh[9]  CurrentClamp   Long Square

# %%
# For AP waveform, with scale ticker

sweep_list = [10]

fig,ax = plt.subplots(figsize = (3,8))

for i in sweep_list:
    sweep = dataset.sweep(i)
    t = sweep.t
    v = sweep.v
    i = sweep.i
    plt.plot(t,v)

plt.xlim([0.605, 0.61])
plt.ylim([-70, 40])

fontprops = fm.FontProperties(size=18)

scalebar = AnchoredSizeBar(plt.gca().transData,
                           0.001, '1 ms', 'lower center', 
                           pad=0.1,
                           color='black',
                           frameon=False,
                           size_vertical=1,
                           fontproperties=fontprops)

plt.gca().add_artist(scalebar)
plt.axis('off')
plt.gca().get_yaxis().set_visible(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [97], in <cell line: 17>()
#      14 plt.xlim([0.605, 0.61])
#      15 plt.ylim([-70, 40])
# ---> 17 fontprops = fm.FontProperties(size=18)
#      19 scalebar = AnchoredSizeBar(plt.gca().transData,
#      20                            0.001, '1 ms', 'lower center',
#      21                            pad=0.1,
#    (...)
#      24                            size_vertical=1,
#      25                            fontproperties=fontprops)
#      27 plt.gca().add_artist(scalebar)
#
# NameError: name 'fm' is not defined

# %%
chirps = dataset.filtered_sweep_table(stimuli=dataset.ontology.chirp_names) # more on this next!
#sweep_set = dataset.sweep_set(long_squares.sweep_number
chirps.sweep_number
#long_squares.columns
chirps
# Out:
#     sweep_number stimulus_units  bridge_balance_mohm   leak_pa  \
# 54            54           Amps            11.294261  6.004333
# 55            55           Amps            11.294261  6.004333
# 56            56           Amps            11.294261  6.004333
# 57            57           Amps            11.294261  6.004333
# 58            58           Amps            11.294261  6.004333
# 59            59           Amps            11.294261  6.004333
# 60            60           Amps            11.294261  6.004333
# 61            61           Amps            11.294261  6.004333
# 62            62           Amps            11.294261  6.004333
# 63            63           Amps            11.294261  6.004333
# 64            64           Amps            11.294261  6.004333
# 65            65           Amps            11.294261  6.004333
# 66            66           Amps            11.294261  6.004333
# 67            67           Amps            11.294261  6.004333
# 68            68           Amps            11.294261  6.004333
# 69            69           Amps            11.294261  6.004333
# 70            70           Amps            11.294261  6.004333
# 71            71           Amps            11.294261  6.004333
# 72            72           Amps            11.294261  6.004333
#
#     capacitance_compensation  sampling_rate  stimulus_scale_factor  \
# 54                  2.000268       200000.0                   10.0
# 55                  2.000268       200000.0                   10.0
# 56                  2.000268       200000.0                   10.0
# 57                  2.000268       200000.0                   10.0
# 58                  2.000268       200000.0                   10.0
# 59                  2.000268       200000.0                   10.0
# 60                  2.000268       200000.0                   10.0
# 61                  2.000268       200000.0                   10.0
# 62                  2.000268       200000.0                   10.0
# 63                  2.000268       200000.0                   10.0
# 64                  2.000268       200000.0                   10.0
# 65                  2.000268       200000.0                   10.0
# 66                  2.000268       200000.0                   10.0
# 67                  2.000268       200000.0                   10.0
# 68                  2.000268       200000.0                   10.0
# 69                  2.000268       200000.0                   10.0
# 70                  2.000268       200000.0                   10.0
# 71                  2.000268       200000.0                   10.0
# 72                  2.000268       200000.0                   10.0
#
#     stimulus_code stimulus_code_ext    clamp_mode stimulus_name
# 54  C2CHIRP180503  C2CHIRP180503[0]  CurrentClamp         Chirp
# 55  C2CHIRP180503  C2CHIRP180503[1]  CurrentClamp         Chirp
# 56  C2CHIRP180503  C2CHIRP180503[2]  CurrentClamp         Chirp
# 57  C2CHIRP180503  C2CHIRP180503[3]  CurrentClamp         Chirp
# 58  C2CHIRP180503  C2CHIRP180503[4]  CurrentClamp         Chirp
# 59  C2CHIRP180503  C2CHIRP180503[5]  CurrentClamp         Chirp
# 60  C2CHIRP180503  C2CHIRP180503[6]  CurrentClamp         Chirp
# 61  C2CHIRP180503  C2CHIRP180503[7]  CurrentClamp         Chirp
# 62  C2CHIRP180503  C2CHIRP180503[8]  CurrentClamp         Chirp
# 63  C2CHIRP180503  C2CHIRP180503[9]  CurrentClamp         Chirp
# 64  C2CHIRP180503  C2CHIRP180503[0]  CurrentClamp         Chirp
# 65  C2CHIRP180503  C2CHIRP180503[1]  CurrentClamp         Chirp
# 66  C2CHIRP180503  C2CHIRP180503[2]  CurrentClamp         Chirp
# 67  C2CHIRP180503  C2CHIRP180503[3]  CurrentClamp         Chirp
# 68  C2CHIRP180503  C2CHIRP180503[4]  CurrentClamp         Chirp
# 69  C2CHIRP180503  C2CHIRP180503[5]  CurrentClamp         Chirp
# 70  C2CHIRP180503  C2CHIRP180503[6]  CurrentClamp         Chirp
# 71  C2CHIRP180503  C2CHIRP180503[7]  CurrentClamp         Chirp
# 72  C2CHIRP180503  C2CHIRP180503[8]  CurrentClamp         Chirp

# %%
ramps = dataset.filtered_sweep_table(stimuli=dataset.ontology.ramp_names) # more on this next!
#sweep_set = dataset.sweep_set(long_squares.sweep_number
ramps.sweep_number
#long_squares.columns
ramps
# Out:
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/ipfx/stimulus.py:90: UserWarning: Could not find stimulus: C2CHIRPB18050
#   warnings.warn("Could not find stimulus: %s" % tag)
#     sweep_number stimulus_units  bridge_balance_mohm    leak_pa  \
# 54            54           Amps              9.70696  25.324471
# 55            55           Amps              9.70696  25.324471
# 56            56           Amps              9.70696  25.324471
#
#     capacitance_compensation  sampling_rate  stimulus_scale_factor  \
# 54                       0.0        50000.0                   10.0
# 55                       0.0        50000.0                   10.0
# 56                       0.0        50000.0                   10.0
#
#    stimulus_code stimulus_code_ext    clamp_mode stimulus_name
# 54        X7Ramp         X7Ramp[0]  CurrentClamp          Ramp
# 55        X7Ramp         X7Ramp[1]  CurrentClamp          Ramp
# 56        X7Ramp         X7Ramp[2]  CurrentClamp          Ramp
