# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pingouin as pg

df_anno = pd.read_feather("anno.feather")

# %%
df_anno
# Out:
#       exp_component_name_id exp_component_name_label exp_component_name_color  \
# 0                      1907      SM-GE4QD_S054_E1-50                  #5D177F
# 1                      1908      SM-GE4QD_S055_E1-50                  #5D177F
# 2                      3626      SM-GE672_S084_E1-50                  #C53C74
# 3                      1920      SM-GE4QD_S067_E1-50                  #5E177F
# 4                      3608      SM-GE672_S065_E1-50                  #C43C75
# ...                     ...                      ...                      ...
# 6759                   1738       SM-D9EQ7_S71_E1-50                  #53137C
# 6760                   1739       SM-D9EQG_S12_E1-50                  #53137D
# 6761                   6758       SQ-80009_S37_E1-50                  #FCFDBF
# 6762                   6759       SQ-80009_S65_E1-50                  #FCFDBF
# 6763                   6762       SQ-80013_S63_E1-50                  #FCFDBF
#
#       layer_id layer_label layer_color  batch_id batch_label batch_color  \
# 0            7           1     #FF8926       131     RSC-205     #E14D66
# 1            7           1     #FF8926       131     RSC-205     #E14D66
# 2           10           3     #FFC74D        79     RSC-139     #7F2482
# 3            7           1     #FF8926       131     RSC-205     #E14D66
# 4            7           1     #FF8926        79     RSC-139     #7F2482
# ...        ...         ...         ...       ...         ...         ...
# 6759        15           5     #919917        68     RSC-092     #6A1C81
# 6760        16           6     #DBFF00        69     RSC-093     #6C1D81
# 6761        14           4     #CCCA3D        25     RSC-046     #19103E
# 6762        14           4     #CCCA3D        25     RSC-046     #19103E
# 6763        14           4     #CCCA3D        25     RSC-046     #19103E
#
#       cell_name_id  ... Tree_first_cor_id Tree_first_cor_color  \
# 0             2624  ...              6331              #FF1515
# 1             2625  ...              6231              #FF1C1C
# 2              403  ...              5560              #FF3838
# 3             2637  ...              4785              #FF5656
# 4              401  ...              4285              #FF6E6E
# ...            ...  ...               ...                  ...
# 6759          4265  ...                 9              #121293
# 6760          4241  ...                 9              #121293
# 6761          4354  ...                 9              #121293
# 6762          4355  ...                 9              #121293
# 6763          4376  ...                 9              #121293
#
#       Tree_second_cor_id Tree_second_cor_color Tree_third_cor_id  \
# 0                   5755               #FF3B3B              5997
# 1                   5770               #FF3A3A              5709
# 2                   5218               #FF5555              5246
# 3                   4499               #FF7979              4998
# 4                   4344               #FF8383              4703
# ...                  ...                   ...               ...
# 6759                   6               #1C1C97                 5
# 6760                   6               #1C1C97                 5
# 6761                   6               #1C1C97                 5
# 6762                   6               #1C1C97                 5
# 6763                   6               #1C1C97                 5
#
#       Tree_third_cor_color Tree_call_id Tree_call_color  Old_call_id  \
# 0                  #FF4848            1         #FF7373            2
# 1                  #FF5D5D            1         #FF7373            2
# 2                  #FF7777            1         #FF7373            2
# 3                  #FF8686            1         #FF7373            2
# 4                  #FF9898            1         #FF7373            2
# ...                    ...          ...             ...          ...
# 6759               #28289D            6         #992E99            4
# 6760               #28289D            6         #992E99            4
# 6761               #28289D            6         #992E99            4
# 6762               #28289D            6         #992E99            4
# 6763               #28289D            6         #992E99            4
#
#      Old_call_color
# 0           #85CC3D
# 1           #85CC3D
# 2           #85CC3D
# 3           #85CC3D
# 4           #85CC3D
# ...             ...
# 6759          #8000
# 6760          #8000
# 6761          #8000
# 6762          #8000
# 6763          #8000
#
# [6764 rows x 253 columns]

# %%
#df_anno.to_csv('anno.csv')

# %%
from datetime import datetime
import re
patch_dates = [str[0:10] for str in df_anno['patch_date_label']]

patch_dates_sub = [str for str in patch_dates if str!='ZZ_Missing']
patch_dates_sub = [str for str in patch_dates if '-' in str]
#patch_dates_sub = [str for str in patch_dates_sub if re.search(str, '-')]
#patch_dates_sub = [str for str in patch_dates_sub if str!='']

dates = []
for date in patch_dates_sub:
    try:
        dates.append(datetime.strptime(date, '%Y-%m-%d'))
    except:
        dates.append(datetime.strptime(date, '%y-%m-%d'))
#dates = [datetime.strptime(date, '%Y-%m-%d') for date in patch_dates_sub]
dates
# Out:
# [datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2017, 12, 20, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2017, 12, 20, 0, 0),
#  datetime.datetime(2018, 6, 11, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2018, 3, 12, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 6, 21, 0, 0),
#  datetime.datetime(2018, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 7, 23, 0, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 6, 20, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2020, 7, 3, 0, 0),
#  datetime.datetime(2018, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2020, 10, 21, 0, 0),
#  datetime.datetime(2021, 2, 19, 0, 0),
#  datetime.datetime(2021, 11, 3, 0, 0),
#  datetime.datetime(2016, 9, 29, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 9, 24, 0, 0),
#  datetime.datetime(2020, 8, 18, 0, 0),
#  datetime.datetime(2021, 11, 3, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 10, 21, 0, 0),
#  datetime.datetime(2022, 4, 26, 0, 0),
#  datetime.datetime(2017, 7, 12, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 5, 24, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2021, 4, 21, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2021, 10, 20, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 8, 13, 0, 0),
#  datetime.datetime(2017, 3, 23, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 7, 23, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2018, 2, 20, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2018, 3, 26, 0, 0),
#  datetime.datetime(2018, 5, 18, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2018, 6, 21, 0, 0),
#  datetime.datetime(2019, 10, 10, 0, 0),
#  datetime.datetime(2019, 10, 10, 0, 0),
#  datetime.datetime(2020, 9, 9, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2019, 7, 23, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 2, 28, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2019, 6, 19, 0, 0),
#  datetime.datetime(2019, 6, 19, 0, 0),
#  datetime.datetime(2019, 6, 19, 0, 0),
#  datetime.datetime(2019, 6, 19, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2020, 1, 23, 0, 0),
#  datetime.datetime(2020, 7, 3, 0, 0),
#  datetime.datetime(2020, 12, 2, 0, 0),
#  datetime.datetime(2021, 5, 19, 0, 0),
#  datetime.datetime(2021, 11, 2, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 4, 2, 0, 0),
#  datetime.datetime(2019, 4, 2, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2020, 3, 4, 0, 0),
#  datetime.datetime(2020, 9, 30, 0, 0),
#  datetime.datetime(2021, 11, 3, 0, 0),
#  datetime.datetime(2021, 11, 10, 0, 0),
#  datetime.datetime(2022, 5, 16, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2020, 8, 19, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2017, 2, 14, 0, 0),
#  datetime.datetime(2019, 11, 22, 0, 0),
#  datetime.datetime(2022, 3, 17, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2021, 5, 26, 0, 0),
#  datetime.datetime(2020, 1, 22, 0, 0),
#  datetime.datetime(2021, 12, 15, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2018, 6, 20, 0, 0),
#  datetime.datetime(2021, 7, 21, 0, 0),
#  datetime.datetime(2022, 5, 16, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2019, 3, 29, 0, 0),
#  datetime.datetime(2020, 6, 9, 0, 0),
#  datetime.datetime(2019, 3, 29, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2017, 6, 14, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2017, 8, 22, 0, 0),
#  datetime.datetime(2017, 10, 17, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2019, 6, 18, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2020, 5, 27, 0, 0),
#  datetime.datetime(2021, 5, 19, 0, 0),
#  datetime.datetime(2021, 8, 4, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 2, 26, 0, 0),
#  datetime.datetime(2022, 3, 8, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2019, 5, 22, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2018, 6, 21, 0, 0),
#  datetime.datetime(2020, 1, 23, 0, 0),
#  datetime.datetime(2019, 7, 31, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2021, 4, 13, 0, 0),
#  datetime.datetime(2019, 9, 9, 0, 0),
#  datetime.datetime(2021, 9, 21, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2019, 12, 12, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2021, 7, 20, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2021, 7, 21, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2021, 11, 10, 0, 0),
#  datetime.datetime(2019, 11, 1, 0, 0),
#  datetime.datetime(2016, 8, 31, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 11, 5, 0, 0),
#  datetime.datetime(2018, 4, 27, 0, 0),
#  datetime.datetime(2019, 3, 29, 0, 0),
#  datetime.datetime(2018, 6, 20, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2021, 2, 19, 0, 0),
#  datetime.datetime(2016, 8, 31, 0, 0),
#  datetime.datetime(2019, 8, 13, 0, 0),
#  datetime.datetime(2017, 5, 23, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2017, 6, 14, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2019, 1, 23, 0, 0),
#  datetime.datetime(2022, 3, 11, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 12, 19, 0, 0),
#  datetime.datetime(2020, 1, 28, 0, 0),
#  datetime.datetime(2020, 10, 2, 0, 0),
#  datetime.datetime(2020, 10, 20, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2020, 12, 11, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2018, 11, 6, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2018, 2, 28, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2019, 10, 17, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2021, 5, 17, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2022, 6, 7, 0, 0),
#  datetime.datetime(2017, 2, 14, 0, 0),
#  datetime.datetime(2018, 2, 21, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2020, 10, 20, 0, 0),
#  datetime.datetime(2022, 3, 23, 0, 0),
#  datetime.datetime(2021, 3, 17, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2021, 8, 4, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2021, 1, 27, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2022, 5, 9, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2019, 3, 13, 0, 0),
#  datetime.datetime(2021, 7, 19, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2019, 5, 24, 0, 0),
#  datetime.datetime(2020, 8, 28, 0, 0),
#  datetime.datetime(2020, 11, 19, 0, 0),
#  datetime.datetime(2021, 5, 14, 0, 0),
#  datetime.datetime(2022, 1, 27, 0, 0),
#  datetime.datetime(2018, 2, 1, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 8, 8, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 11, 22, 0, 0),
#  datetime.datetime(2021, 6, 16, 0, 0),
#  datetime.datetime(2017, 7, 12, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2021, 8, 25, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2018, 4, 27, 0, 0),
#  datetime.datetime(2018, 12, 3, 0, 0),
#  datetime.datetime(2018, 12, 3, 0, 0),
#  datetime.datetime(2019, 7, 15, 0, 0),
#  datetime.datetime(2018, 12, 3, 0, 0),
#  datetime.datetime(2021, 8, 25, 0, 0),
#  datetime.datetime(2019, 10, 10, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2020, 7, 2, 0, 0),
#  datetime.datetime(2021, 8, 25, 0, 0),
#  datetime.datetime(2021, 11, 10, 0, 0),
#  datetime.datetime(2019, 7, 10, 0, 0),
#  datetime.datetime(2020, 12, 2, 0, 0),
#  datetime.datetime(2019, 12, 13, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 1, 23, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2020, 1, 14, 0, 0),
#  datetime.datetime(2019, 2, 11, 0, 0),
#  datetime.datetime(2019, 8, 13, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2021, 3, 3, 0, 0),
#  datetime.datetime(2017, 6, 14, 0, 0),
#  datetime.datetime(2021, 11, 3, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2017, 10, 11, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2020, 8, 28, 0, 0),
#  datetime.datetime(2020, 6, 24, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2020, 8, 5, 0, 0),
#  datetime.datetime(2020, 11, 6, 0, 0),
#  datetime.datetime(2018, 12, 19, 0, 0),
#  datetime.datetime(2022, 1, 12, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 10, 3, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2022, 3, 23, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2017, 8, 21, 0, 0),
#  datetime.datetime(2018, 11, 7, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 10, 26, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2021, 8, 25, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2019, 4, 2, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2021, 11, 10, 0, 0),
#  datetime.datetime(2022, 5, 17, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2019, 8, 26, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2019, 7, 15, 0, 0),
#  datetime.datetime(2019, 7, 30, 0, 0),
#  datetime.datetime(2019, 1, 15, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2016, 5, 20, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2019, 6, 4, 0, 0),
#  datetime.datetime(2022, 2, 3, 0, 0),
#  datetime.datetime(2017, 9, 19, 0, 0),
#  datetime.datetime(2019, 12, 3, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2022, 3, 3, 0, 0),
#  datetime.datetime(2018, 2, 20, 0, 0),
#  datetime.datetime(2021, 2, 19, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2018, 8, 22, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2019, 10, 3, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2019, 8, 26, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2021, 7, 27, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2018, 6, 21, 0, 0),
#  datetime.datetime(2018, 5, 10, 0, 0),
#  datetime.datetime(2018, 3, 13, 0, 0),
#  datetime.datetime(2020, 6, 11, 0, 0),
#  datetime.datetime(2019, 7, 23, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2017, 12, 19, 0, 0),
#  datetime.datetime(2019, 9, 12, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 2, 20, 0, 0),
#  datetime.datetime(2018, 2, 22, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2019, 7, 31, 0, 0),
#  datetime.datetime(2017, 11, 27, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 5, 10, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2017, 8, 21, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2017, 7, 12, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 6, 21, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2021, 11, 2, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2018, 12, 18, 0, 0),
#  datetime.datetime(2021, 10, 12, 0, 0),
#  datetime.datetime(2021, 7, 19, 0, 0),
#  datetime.datetime(2022, 6, 7, 0, 0),
#  datetime.datetime(2018, 5, 23, 0, 0),
#  datetime.datetime(2020, 6, 19, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 9, 28, 0, 0),
#  datetime.datetime(2020, 7, 17, 0, 0),
#  datetime.datetime(2019, 9, 3, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2022, 2, 11, 0, 0),
#  datetime.datetime(2020, 6, 19, 0, 0),
#  datetime.datetime(2019, 10, 3, 0, 0),
#  datetime.datetime(2020, 10, 26, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2017, 5, 23, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2022, 3, 2, 0, 0),
#  datetime.datetime(2019, 7, 25, 0, 0),
#  datetime.datetime(2020, 7, 2, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2019, 1, 31, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2020, 5, 19, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2020, 11, 24, 0, 0),
#  datetime.datetime(2019, 6, 18, 0, 0),
#  datetime.datetime(2020, 2, 4, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2020, 12, 11, 0, 0),
#  datetime.datetime(2018, 10, 4, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2018, 7, 3, 0, 0),
#  datetime.datetime(2019, 4, 8, 0, 0),
#  datetime.datetime(2019, 6, 25, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2018, 3, 21, 0, 0),
#  datetime.datetime(2020, 1, 27, 0, 0),
#  datetime.datetime(2019, 6, 25, 0, 0),
#  datetime.datetime(2021, 2, 24, 0, 0),
#  datetime.datetime(2019, 9, 9, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 10, 28, 0, 0),
#  datetime.datetime(2020, 1, 28, 0, 0),
#  datetime.datetime(2021, 2, 24, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2020, 12, 9, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2019, 5, 20, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2019, 5, 22, 0, 0),
#  datetime.datetime(2019, 12, 4, 0, 0),
#  datetime.datetime(2018, 12, 3, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2019, 2, 7, 0, 0),
#  datetime.datetime(2019, 2, 7, 0, 0),
#  datetime.datetime(2019, 11, 29, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2020, 5, 26, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 1, 27, 0, 0),
#  datetime.datetime(2021, 11, 11, 0, 0),
#  datetime.datetime(2021, 1, 20, 0, 0),
#  datetime.datetime(2020, 8, 4, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 3, 19, 0, 0),
#  datetime.datetime(2018, 9, 14, 0, 0),
#  datetime.datetime(2020, 5, 22, 0, 0),
#  datetime.datetime(2019, 12, 5, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2019, 7, 25, 0, 0),
#  datetime.datetime(2019, 9, 12, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2017, 12, 7, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2022, 5, 17, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2021, 5, 19, 0, 0),
#  datetime.datetime(2020, 12, 9, 0, 0),
#  datetime.datetime(2019, 4, 22, 0, 0),
#  datetime.datetime(2018, 12, 17, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2019, 7, 31, 0, 0),
#  datetime.datetime(2019, 5, 22, 0, 0),
#  datetime.datetime(2022, 3, 9, 0, 0),
#  datetime.datetime(2016, 9, 29, 0, 0),
#  datetime.datetime(2021, 1, 29, 0, 0),
#  datetime.datetime(2020, 12, 2, 0, 0),
#  datetime.datetime(2019, 6, 24, 0, 0),
#  datetime.datetime(2019, 7, 30, 0, 0),
#  datetime.datetime(2016, 6, 28, 0, 0),
#  datetime.datetime(2018, 10, 3, 0, 0),
#  datetime.datetime(2022, 2, 11, 0, 0),
#  datetime.datetime(2021, 11, 22, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2019, 8, 26, 0, 0),
#  datetime.datetime(2020, 5, 27, 0, 0),
#  datetime.datetime(2020, 11, 24, 0, 0),
#  datetime.datetime(2022, 2, 18, 0, 0),
#  datetime.datetime(2022, 5, 11, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 7, 30, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2018, 8, 30, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2021, 1, 12, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2020, 12, 8, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2022, 5, 11, 0, 0),
#  datetime.datetime(2021, 1, 12, 0, 0),
#  datetime.datetime(2019, 3, 29, 0, 0),
#  datetime.datetime(2022, 3, 30, 0, 0),
#  datetime.datetime(2020, 10, 21, 0, 0),
#  datetime.datetime(2021, 2, 2, 0, 0),
#  datetime.datetime(2019, 4, 12, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2016, 7, 19, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2017, 10, 26, 0, 0),
#  datetime.datetime(2019, 6, 10, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2020, 7, 22, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2019, 7, 25, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2022, 4, 28, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2019, 6, 7, 0, 0),
#  datetime.datetime(2016, 8, 26, 0, 0),
#  datetime.datetime(2019, 8, 27, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2020, 12, 9, 0, 0),
#  datetime.datetime(2018, 6, 13, 0, 0),
#  datetime.datetime(2021, 11, 10, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2018, 6, 20, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2019, 5, 9, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2017, 8, 21, 0, 0),
#  datetime.datetime(2018, 10, 3, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 6, 18, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2019, 1, 8, 0, 0),
#  datetime.datetime(2021, 2, 17, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2019, 4, 8, 0, 0),
#  datetime.datetime(2019, 4, 15, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2020, 7, 22, 0, 0),
#  datetime.datetime(2018, 10, 23, 0, 0),
#  datetime.datetime(2019, 1, 22, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 4, 8, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2019, 5, 7, 0, 0),
#  datetime.datetime(2018, 10, 22, 0, 0),
#  datetime.datetime(2019, 6, 4, 0, 0),
#  datetime.datetime(2019, 9, 24, 0, 0),
#  datetime.datetime(2018, 3, 9, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2020, 1, 27, 0, 0),
#  datetime.datetime(2020, 5, 22, 0, 0),
#  datetime.datetime(2022, 1, 27, 0, 0),
#  datetime.datetime(2017, 12, 20, 0, 0),
#  datetime.datetime(2018, 6, 11, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2020, 7, 20, 0, 0),
#  datetime.datetime(2021, 6, 29, 0, 0),
#  datetime.datetime(2017, 6, 15, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2019, 4, 19, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2018, 9, 28, 0, 0),
#  datetime.datetime(2020, 10, 13, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2019, 3, 5, 0, 0),
#  datetime.datetime(2020, 1, 27, 0, 0),
#  datetime.datetime(2019, 1, 25, 0, 0),
#  datetime.datetime(2019, 10, 3, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2019, 7, 22, 0, 0),
#  datetime.datetime(2017, 2, 1, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2019, 5, 14, 0, 0),
#  datetime.datetime(2017, 10, 11, 0, 0),
#  datetime.datetime(2021, 12, 15, 0, 0),
#  datetime.datetime(2020, 10, 30, 0, 0),
#  datetime.datetime(2019, 9, 9, 0, 0),
#  datetime.datetime(2018, 2, 27, 0, 0),
#  datetime.datetime(2020, 6, 19, 0, 0),
#  datetime.datetime(2020, 10, 20, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2019, 11, 15, 0, 0),
#  datetime.datetime(2019, 8, 20, 0, 0),
#  datetime.datetime(2018, 6, 11, 0, 0),
#  datetime.datetime(2021, 6, 29, 0, 0),
#  datetime.datetime(2018, 12, 19, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2019, 6, 3, 0, 0),
#  datetime.datetime(2017, 10, 16, 0, 0),
#  datetime.datetime(2017, 6, 15, 0, 0),
#  datetime.datetime(2018, 3, 26, 0, 0),
#  datetime.datetime(2019, 9, 9, 0, 0),
#  datetime.datetime(2019, 4, 9, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2019, 4, 23, 0, 0),
#  datetime.datetime(2019, 6, 25, 0, 0),
#  datetime.datetime(2020, 7, 21, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 9, 14, 0, 0),
#  datetime.datetime(2018, 1, 9, 0, 0),
#  datetime.datetime(2017, 10, 13, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2022, 3, 24, 0, 0),
#  datetime.datetime(2018, 9, 27, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2018, 5, 22, 0, 0),
#  datetime.datetime(2019, 3, 21, 0, 0),
#  datetime.datetime(2020, 12, 9, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2022, 2, 16, 0, 0),
#  datetime.datetime(2021, 12, 15, 0, 0),
#  datetime.datetime(2019, 7, 15, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2022, 2, 16, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2019, 6, 20, 0, 0),
#  datetime.datetime(2019, 10, 3, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2022, 3, 2, 0, 0),
#  datetime.datetime(2019, 2, 15, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2021, 9, 10, 0, 0),
#  datetime.datetime(2018, 9, 12, 0, 0),
#  datetime.datetime(2020, 1, 28, 0, 0),
#  datetime.datetime(2019, 5, 24, 0, 0),
#  datetime.datetime(2020, 1, 23, 0, 0),
#  datetime.datetime(2021, 6, 29, 0, 0),
#  datetime.datetime(2018, 2, 28, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2017, 5, 30, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2021, 8, 18, 0, 0),
#  datetime.datetime(2022, 1, 20, 0, 0),
#  datetime.datetime(2017, 8, 21, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2021, 8, 18, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 10, 23, 0, 0),
#  datetime.datetime(2019, 9, 3, 0, 0),
#  datetime.datetime(2020, 5, 27, 0, 0),
#  datetime.datetime(2021, 8, 19, 0, 0),
#  datetime.datetime(2022, 1, 24, 0, 0),
#  datetime.datetime(2018, 2, 7, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2022, 1, 27, 0, 0),
#  datetime.datetime(2018, 10, 2, 0, 0),
#  datetime.datetime(2018, 10, 5, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2019, 7, 31, 0, 0),
#  datetime.datetime(2019, 8, 8, 0, 0),
#  datetime.datetime(2020, 6, 2, 0, 0),
#  datetime.datetime(2020, 1, 24, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2021, 5, 7, 0, 0),
#  datetime.datetime(2021, 10, 6, 0, 0),
#  datetime.datetime(2021, 5, 5, 0, 0),
#  datetime.datetime(2022, 1, 18, 0, 0),
#  datetime.datetime(2019, 6, 13, 0, 0),
#  datetime.datetime(2020, 2, 7, 0, 0),
#  datetime.datetime(2022, 1, 24, 0, 0),
#  datetime.datetime(2018, 8, 24, 0, 0),
#  datetime.datetime(2021, 6, 10, 0, 0),
#  datetime.datetime(2021, 8, 19, 0, 0),
#  datetime.datetime(2021, 6, 10, 0, 0),
#  datetime.datetime(2021, 6, 10, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2021, 5, 7, 0, 0),
#  datetime.datetime(2019, 6, 11, 0, 0),
#  datetime.datetime(2021, 6, 9, 0, 0),
#  datetime.datetime(2021, 6, 9, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2016, 8, 9, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2019, 5, 24, 0, 0),
#  datetime.datetime(2021, 5, 19, 0, 0),
#  datetime.datetime(2021, 11, 2, 0, 0),
#  datetime.datetime(2018, 2, 7, 0, 0),
#  datetime.datetime(2019, 10, 15, 0, 0),
#  datetime.datetime(2021, 2, 16, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2017, 12, 12, 0, 0),
#  datetime.datetime(2021, 6, 15, 0, 0),
#  datetime.datetime(2021, 2, 16, 0, 0),
#  datetime.datetime(2017, 3, 23, 0, 0),
#  datetime.datetime(2018, 2, 20, 0, 0),
#  datetime.datetime(2018, 4, 24, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 11, 28, 0, 0),
#  datetime.datetime(2019, 10, 16, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2020, 1, 22, 0, 0),
#  datetime.datetime(2021, 2, 16, 0, 0),
#  datetime.datetime(2018, 3, 27, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2017, 6, 15, 0, 0),
#  datetime.datetime(2018, 7, 3, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2018, 10, 23, 0, 0),
#  datetime.datetime(2018, 3, 27, 0, 0),
#  datetime.datetime(2018, 1, 25, 0, 0),
#  datetime.datetime(2018, 3, 26, 0, 0),
#  datetime.datetime(2020, 7, 9, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2016, 8, 16, 0, 0),
#  datetime.datetime(2018, 7, 3, 0, 0),
#  datetime.datetime(2022, 2, 3, 0, 0),
#  datetime.datetime(2019, 6, 19, 0, 0),
#  datetime.datetime(2020, 10, 9, 0, 0),
#  datetime.datetime(2021, 11, 11, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2021, 4, 13, 0, 0),
#  datetime.datetime(2021, 8, 17, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2018, 4, 17, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2019, 7, 16, 0, 0),
#  datetime.datetime(2022, 5, 4, 0, 0),
#  datetime.datetime(2017, 3, 1, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 3, 27, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2022, 4, 21, 0, 0),
#  datetime.datetime(2018, 9, 19, 0, 0),
#  datetime.datetime(2019, 1, 30, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2022, 3, 21, 0, 0),
#  datetime.datetime(2021, 8, 18, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2020, 7, 2, 0, 0),
#  datetime.datetime(2021, 10, 12, 0, 0),
#  datetime.datetime(2017, 6, 15, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2018, 4, 27, 0, 0),
#  datetime.datetime(2018, 11, 7, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 2, 22, 0, 0),
#  datetime.datetime(2018, 9, 26, 0, 0),
#  datetime.datetime(2021, 8, 27, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2019, 4, 25, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2018, 10, 26, 0, 0),
#  datetime.datetime(2018, 6, 11, 0, 0),
#  datetime.datetime(2018, 8, 16, 0, 0),
#  datetime.datetime(2018, 3, 27, 0, 0),
#  datetime.datetime(2018, 7, 17, 0, 0),
#  datetime.datetime(2018, 5, 23, 0, 0),
#  datetime.datetime(2018, 8, 8, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2019, 11, 13, 0, 0),
#  datetime.datetime(2021, 4, 27, 0, 0),
#  datetime.datetime(2021, 8, 18, 0, 0),
#  datetime.datetime(2017, 6, 13, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2022, 1, 31, 0, 0),
#  datetime.datetime(2021, 12, 15, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 2, 21, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2018, 11, 6, 0, 0),
#  datetime.datetime(2018, 9, 25, 0, 0),
#  datetime.datetime(2019, 11, 22, 0, 0),
#  datetime.datetime(2017, 6, 20, 0, 0),
#  datetime.datetime(2022, 2, 3, 0, 0),
#  datetime.datetime(2019, 4, 16, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2018, 10, 25, 0, 0),
#  datetime.datetime(2019, 3, 11, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2019, 7, 9, 0, 0),
#  datetime.datetime(2018, 10, 30, 0, 0),
#  datetime.datetime(2018, 3, 20, 0, 0),
#  datetime.datetime(2022, 1, 27, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2022, 1, 21, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2016, 8, 26, 0, 0),
#  datetime.datetime(2018, 12, 11, 0, 0),
#  datetime.datetime(2021, 4, 27, 0, 0),
#  datetime.datetime(2017, 7, 11, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2018, 11, 6, 0, 0),
#  datetime.datetime(2019, 3, 13, 0, 0),
#  datetime.datetime(2022, 4, 20, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2018, 3, 9, 0, 0),
#  datetime.datetime(2019, 2, 26, 0, 0),
#  datetime.datetime(2022, 5, 6, 0, 0),
#  datetime.datetime(2016, 7, 19, 0, 0),
#  datetime.datetime(2018, 8, 7, 0, 0),
#  datetime.datetime(2018, 11, 27, 0, 0),
#  datetime.datetime(2016, 8, 31, 0, 0),
#  datetime.datetime(2017, 5, 31, 0, 0),
#  datetime.datetime(2019, 2, 15, 0, 0),
#  datetime.datetime(2020, 7, 9, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2018, 12, 12, 0, 0),
#  datetime.datetime(2021, 7, 27, 0, 0),
#  datetime.datetime(2016, 6, 28, 0, 0),
#  datetime.datetime(2018, 8, 22, 0, 0),
#  datetime.datetime(2018, 11, 20, 0, 0),
#  datetime.datetime(2020, 1, 21, 0, 0),
#  datetime.datetime(2017, 5, 23, 0, 0),
#  datetime.datetime(2017, 12, 5, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2020, 1, 22, 0, 0),
#  datetime.datetime(2018, 7, 18, 0, 0),
#  datetime.datetime(2018, 6, 13, 0, 0),
#  datetime.datetime(2018, 8, 15, 0, 0),
#  datetime.datetime(2022, 3, 8, 0, 0),
#  datetime.datetime(2020, 2, 25, 0, 0),
#  datetime.datetime(2021, 11, 9, 0, 0),
#  datetime.datetime(2018, 5, 8, 0, 0),
#  datetime.datetime(2016, 6, 28, 0, 0),
#  datetime.datetime(2017, 10, 10, 0, 0),
#  ...]

# %%
np.array(patch_dates)!='ZZ_Missing'
# Out:
# array(True)

# %%
df_anno.columns.values
# Out:
# array(['exp_component_name_id', 'exp_component_name_label',
#        'exp_component_name_color', 'layer_id', 'layer_label',
#        'layer_color', 'batch_id', 'batch_label', 'batch_color',
#        'cell_name_id', 'cell_name_label', 'cell_name_color', 'spec_id_id',
#        'spec_id_label', 'spec_id_color', 'donor_id', 'donor_label',
#        'donor_color', 'collaborator_id', 'collaborator_label',
#        'collaborator_color', 'gender_id', 'gender_label', 'gender_color',
#        'collection_id', 'collection_label', 'collection_color',
#        'medical_conditions_id', 'medical_conditions_label',
#        'medical_conditions_color', 'postPatch_id', 'postPatch_label',
#        'postPatch_color', 'postPatch_classification_id',
#        'postPatch_classification_label', 'postPatch_classification_color',
#        'filldate_id', 'filldate_label', 'filldate_color',
#        'rigOperator_id', 'rigOperator_label', 'rigOperator_color',
#        'rigNumber_id', 'rigNumber_label', 'rigNumber_color',
#        'cell_depth_id', 'cell_depth_label', 'cell_depth_color',
#        'sliceHealth_id', 'sliceHealth_label', 'sliceHealth_color',
#        'patchseq_roi_id', 'patchseq_roi_label', 'patchseq_roi_color',
#        'roi_id', 'roi_label', 'roi_color', 'Class_id', 'Class_label',
#        'Class_color', 'injection_roi_id', 'injection_roi_label',
#        'injection_roi_color', 'injection_method_id',
#        'injection_method_label', 'injection_method_color',
#        'injection_materials_id', 'injection_materials_label',
#        'injection_materials_color', 'propagation_type_id',
#        'propagation_type_label', 'propagation_type_color',
#        'Total_time_id', 'Total_time_label', 'Total_time_color',
#        'Ephys_time_id', 'Ephys_time_label', 'Ephys_time_color',
#        'Retraction_time_id', 'Retraction_time_label',
#        'Retraction_time_color', 'endPipetteR_id', 'endPipetteR_label',
#        'endPipetteR_color', 'rna_amplification_pass_fail_id',
#        'rna_amplification_pass_fail_label',
#        'rna_amplification_pass_fail_color', 'go_no_go_63x_id',
#        'go_no_go_63x_label', 'go_no_go_63x_color',
#        'image_series_63x_qc_id', 'image_series_63x_qc_label',
#        'image_series_63x_qc_color', 'cell_specimen_project_id',
#        'cell_specimen_project_label', 'cell_specimen_project_color',
#        'percent_reads_aligned_total_id',
#        'percent_reads_aligned_total_label',
#        'percent_reads_aligned_total_color',
#        'percent_reads_aligned_to_exons_id',
#        'percent_reads_aligned_to_exons_label',
#        'percent_reads_aligned_to_exons_color', 'genes_id', 'genes_label',
#        'genes_color', 'patch_date_id', 'patch_date_label',
#        'patch_date_color', 'exclude_id', 'exclude_label', 'exclude_color',
#        'fpkm_dir_id', 'fpkm_dir_label', 'fpkm_dir_color', 'MALAT1_cpm_id',
#        'MALAT1_cpm_label', 'MALAT1_cpm_color',
#        'Depth_from_Pia_microns_id', 'Depth_from_Pia_microns_label',
#        'Depth_from_Pia_microns_color', 'total_cortical_depth_id',
#        'total_cortical_depth_label', 'total_cortical_depth_color',
#        'L23_cell_depth_id', 'L23_cell_depth_label',
#        'L23_cell_depth_color', 'L23_total_thickness_id',
#        'L23_total_thickness_label', 'L23_total_thickness_color',
#        'virus_id', 'virus_label', 'virus_color',
#        'recon_cell_overall_state_id', 'recon_cell_overall_state_label',
#        'recon_cell_overall_state_color', 'recon_layer_type_id',
#        'recon_layer_type_label', 'recon_layer_type_color',
#        'cluster_label', 'score_id', 'score_label', 'score_color',
#        'n_marker_id', 'n_marker_label', 'n_marker_color', 'res_index_id',
#        'res_index_label', 'res_index_color', 'h_score_id',
#        'h_score_label', 'h_score_color', 'res_index_pctile_id',
#        'res_index_pctile_label', 'res_index_pctile_color',
#        'topLeafValue_id', 'topLeafValue_label', 'topLeafValue_color',
#        'last_map_id', 'last_map_label', 'last_map_color', 'last_res_id',
#        'last_res_label', 'last_res_color', 'last_score_id',
#        'last_score_label', 'last_score_color', 'code_version_id',
#        'code_version_label', 'code_version_color', 'ref_version_id',
#        'ref_version_label', 'ref_version_color', 'mapping_version_id',
#        'mapping_version_label', 'mapping_version_color', 'sample_id',
#        'cell_reporter', 'marker_genes', 'topLeaf_label', 'cluster_color',
#        'cluster_id', 'topLeaf_id', 'topLeaf_color', 'dendcluster_color',
#        'quality_score_label', 'marker_sum_norm_label',
#        'Norm_Marker_Sum.0.4_label', 'contaminationType_label',
#        'contam_sum_label', 'quality_score_id', 'quality_score_color',
#        'marker_sum_norm_id', 'marker_sum_norm_color', 'contam_sum_id',
#        'contam_sum_color', 'Norm_Marker_Sum.0.4_id',
#        'Norm_Marker_Sum.0.4_color', 'contaminationType_id',
#        'contaminationType_color', 'seurat_cluster_label',
#        'seurat_prediction_score_label', 'seurat_cluster_id',
#        'seurat_cluster_color', 'seurat_prediction_score_id',
#        'seurat_prediction_score_color', 'broad_class_label',
#        'subclass_label', 'broad_class_id', 'broad_class_color',
#        'subclass_id', 'subclass_color', 'Tree_first_cl_label',
#        'Tree_second_cl_label', 'Tree_third_cl_label',
#        'Tree_first_bt_label', 'Tree_second_bt_label',
#        'Tree_third_bt_label', 'Tree_first_KL_label',
#        'Tree_second_KL_label', 'Tree_third_KL_label',
#        'Tree_first_cor_label', 'Tree_second_cor_label',
#        'Tree_third_cor_label', 'Tree_call_label', 'Old_call_label',
#        'Tree_first_cl_id', 'Tree_first_cl_color', 'Tree_second_cl_id',
#        'Tree_second_cl_color', 'Tree_third_cl_id', 'Tree_third_cl_color',
#        'Tree_first_bt_id', 'Tree_first_bt_color', 'Tree_second_bt_id',
#        'Tree_second_bt_color', 'Tree_third_bt_id', 'Tree_third_bt_color',
#        'Tree_first_KL_id', 'Tree_first_KL_color', 'Tree_second_KL_id',
#        'Tree_second_KL_color', 'Tree_third_KL_id', 'Tree_third_KL_color',
#        'Tree_first_cor_id', 'Tree_first_cor_color', 'Tree_second_cor_id',
#        'Tree_second_cor_color', 'Tree_third_cor_id',
#        'Tree_third_cor_color', 'Tree_call_id', 'Tree_call_color',
#        'Old_call_id', 'Old_call_color'], dtype=object)

# %%
df_anno.cell_name_label
# Out:
# 0        H19.06.351.11.16.01.01
# 1        H19.06.351.11.16.01.03
# 2           H17.03.016.11.16.02
# 3        H19.06.351.11.16.02.06
# 4           H17.03.016.11.15.07
#                  ...
# 6759    H200.1023.CX.09.013.519
# 6760    H200.1023.CX.09.010.364
# 6761      H200.1030.CX10.03.741
# 6762      H200.1030.CX10.03.761
# 6763      H200.1030.CX10.04.655
# Name: cell_name_label, Length: 6764, dtype: object

# %%
df_anno.cell_name_id
# Out:
# 0       2624
# 1       2625
# 2        403
# 3       2637
# 4        401
#         ...
# 6759    4265
# 6760    4241
# 6761    4354
# 6762    4355
# 6763    4376
# Name: cell_name_id, Length: 6764, dtype: int32

# %%
df_ephys = pd.read_csv("snakemake_ephys/Human_ephys_features.csv")

# %%
df_ephys
# Out:
#        cell_name  blowout_mv_qc  electrode_0_pa_qc    recording_date_qc  \
# 0     1216190688            NaN         -28.166876  2022-10-07 01:39:16
# 1      685821031            NaN          73.722504  2018-04-18 06:13:27
# 2      768857541            NaN         -17.188749  2018-10-25 23:43:15
# 3     1027257544            NaN          48.111252  2020-06-02 00:06:21
# 4     1216879626            NaN           6.715000  2022-10-10 23:06:22
# ...          ...            ...                ...                  ...
# 3679   835596603            NaN         -21.753750  2019-03-11 21:00:49
# 3680  1030496341            NaN           0.032500  2020-06-17 19:07:27
# 3681   700835777            NaN          84.870003  2018-05-22 23:50:34
# 3682   832565636            NaN         -59.684376  2019-03-05 22:53:42
# 3683   923084897            NaN          18.625000  2019-08-14 02:04:28
#
#       seal_gohm_qc  input_resistance_mohm_qc  \
# 0         2.062001                 54.049500
# 1         1.498305                508.300256
# 2         2.987128                116.592264
# 3         2.120645                220.395920
# 4         2.698770                506.166688
# ...            ...                       ...
# 3679      1.322570                528.508128
# 3680      3.598487                554.526528
# 3681      2.392445                116.194728
# 3682      1.738198                302.473888
# 3683      1.863780                248.909952
#
#       initial_access_resistance_mohm_qc  input_access_resistance_ratio_qc  \
# 0                              6.201563                          0.114739
# 1                              8.984607                          0.017676
# 2                             10.590369                          0.090833
# 3                             10.664127                          0.048386
# 4                              8.311236                          0.016420
# ...                                 ...                               ...
# 3679                          12.157125                          0.023003
# 3680                           9.733315                          0.017552
# 3681                          11.817028                          0.101700
# 3682                          19.322564                          0.063882
# 3683                           9.264183                          0.037219
#
#      fail_tags_qc  failed_blowout  ...  peak_deltav_ramp  peak_ratio_chirp  \
# 0             NaN           False  ...               NaN               NaN
# 1             NaN           False  ...         88.031254          1.024661
# 2             NaN           False  ...         80.885939               NaN
# 3             NaN           False  ...         47.795835          1.032767
# 4             NaN           False  ...               NaN               NaN
# ...           ...             ...  ...               ...               ...
# 3679          NaN           False  ...         80.472919          1.020596
# 3680          NaN           False  ...         73.952085          1.002711
# 3681          NaN           False  ...         55.968750          1.001094
# 3682          NaN           False  ...         66.879168               NaN
# 3683          NaN           False  ...         66.708335          1.001188
#
#       peak_freq_chirp  3db_freq_chirp peak_impedance_chirp  \
# 0                 NaN             NaN                  NaN
# 1            1.000400        9.303721             0.319072
# 2                 NaN             NaN                  NaN
# 3            1.900566        5.851744             0.298725
# 4                 NaN             NaN                  NaN
# ...               ...             ...                  ...
# 3679         1.550462        8.102415             0.481901
# 3680         0.400119        3.250969             0.572866
# 3681         0.400119       13.804114             0.147218
# 3682              NaN             NaN                  NaN
# 3683         0.400119        6.301878             0.328596
#
#      low_freq_impedance_chirp sync_freq_chirp phase_peak_chirp  \
# 0                         NaN             NaN              NaN
# 1                    0.311393        0.400160        -0.093382
# 2                         NaN             NaN              NaN
# 3                    0.289248        0.600179        -0.247775
# 4                         NaN             NaN              NaN
# ...                       ...             ...              ...
# 3679                 0.472176        0.750224        -0.131442
# 3680                 0.571317        0.400119        -0.124863
# 3681                 0.147057        0.400119        -0.024377
# 3682                      NaN             NaN              NaN
# 3683                 0.328206        0.400119        -0.056896
#
#      phase_low_chirp  total_inductive_phase_chirp
# 0                NaN                          NaN
# 1           0.001045                     0.000105
# 2                NaN                          NaN
# 3           0.044893                     0.001179
# 4                NaN                          NaN
# ...              ...                          ...
# 3679        0.053782                     0.001356
# 3680       -0.124863                     0.000000
# 3681       -0.024377                     0.000000
# 3682             NaN                          NaN
# 3683       -0.056896                     0.000000
#
# [3684 rows x 111 columns]

# %%
df_ephys.columns.values
# Out:
# array(['cell_name', 'blowout_mv_qc', 'electrode_0_pa_qc',
#        'recording_date_qc', 'seal_gohm_qc', 'input_resistance_mohm_qc',
#        'initial_access_resistance_mohm_qc',
#        'input_access_resistance_ratio_qc', 'fail_tags_qc',
#        'failed_blowout', 'failed_electrode_0', 'failed_seal',
#        'failed_input_access_resistance', 'failed_qc',
#        'failed_fx_long_squares', 'failed_fx_short_squares',
#        'failed_fx_ramps', 'failed_fx_chirps', 'failed_fx_sweep_features',
#        'upstroke_downstroke_ratio_short_square',
#        'threshold_v_short_square', 'width_short_square',
#        'upstroke_short_square', 'downstroke_short_square',
#        'width_suprathresh_short_square', 'peak_deltav_short_square',
#        'sag', 'sag_area', 'sag_tau', 'v_baseline', 'rheobase_i',
#        'fi_fit_slope', 'vm_for_sag', 'input_resistance',
#        'input_resistance_ss', 'tau', 'latency_rheo', 'avg_rate_rheo',
#        'mean_isi_rheo', 'upstroke_downstroke_ratio_rheo',
#        'threshold_v_rheo', 'peak_v_rheo', 'width_rheo', 'upstroke_rheo',
#        'downstroke_rheo', 'width_suprathresh_rheo', 'trough_v_rheo',
#        'fast_trough_v_rheo', 'postap_slope_rheo',
#        'fast_trough_v_last_rheo', 'adp_v_last_rheo', 'adapt_hero',
#        'avg_rate_hero', 'latency_hero', 'mean_isi_hero',
#        'median_isi_hero', 'isi_cv_hero', 'ir_late_hero',
#        'upstroke_downstroke_ratio_hero', 'threshold_v_hero',
#        'peak_v_hero', 'width_hero', 'upstroke_hero', 'downstroke_hero',
#        'width_suprathresh_hero', 'trough_v_hero', 'fast_trough_v_hero',
#        'postap_slope_hero', 'ahp_delay_ratio_hero', 'sag_depol',
#        'sag_area_depol', 'sag_tau_depol', 'adapt_mean', 'isi_cv_mean',
#        'ir_late_mean', 'avg_rate_max', 'isi_adapt_ratio',
#        'width_adapt_ratio', 'upstroke_adapt_ratio',
#        'downstroke_adapt_ratio', 'threshold_v_adapt_ratio',
#        'peak_v_adapt_ratio', 'ahp_delay_ratio_5spike',
#        'trough_slowdeltav_rheo', 'trough_slowdeltav_hero',
#        'fast_trough_deltav_rheo', 'fast_trough_deltav_hero',
#        'peak_deltav_rheo', 'peak_deltav_hero', 'first_isi_inv_rheo',
#        'first_isi_inv_hero', 'upstroke_downstroke_ratio_ramp',
#        'threshold_v_ramp', 'width_ramp', 'upstroke_ramp',
#        'downstroke_ramp', 'width_suprathresh_ramp', 'trough_v_ramp',
#        'threshold_i_ramp', 'postap_slope_ramp', 'fast_trough_deltav_ramp',
#        'peak_deltav_ramp', 'peak_ratio_chirp', 'peak_freq_chirp',
#        '3db_freq_chirp', 'peak_impedance_chirp',
#        'low_freq_impedance_chirp', 'sync_freq_chirp', 'phase_peak_chirp',
#        'phase_low_chirp', 'total_inductive_phase_chirp'], dtype=object)

# %%
df_id = pd.read_csv("custom_report.csv")

# %%
df_id
# Out:
#          project   cell_specimen_id   \
# 0      hIVSCC-MET          541549258
# 1      hIVSCC-MET          541549258
# 2      hIVSCC-MET          541557114
# 3      hIVSCC-MET          541557114
# 4      hIVSCC-MET          569835804
# ...           ...                ...
# 3868  hIVSCC-METc         1263787547
# 3869  hIVSCC-METc         1263798528
# 3870  hIVSCC-METc         1263825709
# 3871  hIVSCC-METc         1263839935
# 3872  hIVSCC-METc         1263853788
#
#                                     link_cell_specimen   \
# 0     =HYPERLINK("http://lims2/specimens?id=541549258")
# 1     =HYPERLINK("http://lims2/specimens?id=541549258")
# 2     =HYPERLINK("http://lims2/specimens?id=541557114")
# 3     =HYPERLINK("http://lims2/specimens?id=541557114")
# 4     =HYPERLINK("http://lims2/specimens?id=569835804")
# ...                                                 ...
# 3868  =HYPERLINK("http://lims2/specimens?id=12637875...
# 3869  =HYPERLINK("http://lims2/specimens?id=12637985...
# 3870  =HYPERLINK("http://lims2/specimens?id=12638257...
# 3871  =HYPERLINK("http://lims2/specimens?id=12638399...
# 3872  =HYPERLINK("http://lims2/specimens?id=12638537...
#
#          cell_specimen_name  cell_or_cluster  hemisphere      flipped   \
# 0     H16.03.007.01.01.05.07             Cell        left  not flipped
# 1     H16.03.007.01.01.05.07             Cell        left  not flipped
# 2     H16.03.007.01.01.05.10             Cell        left  not flipped
# 3     H16.03.007.01.01.05.10             Cell        left  not flipped
# 4        H17.03.002.11.09.04             Cell       right  not checked
# ...                      ...              ...         ...          ...
# 3868  H23.26.404.11.74.01.02             Cell         NaN  not checked
# 3869  H23.26.404.11.74.01.03             Cell         NaN  not checked
# 3870  H23.26.404.11.74.01.04             Cell         NaN  not checked
# 3871  H23.26.404.11.74.01.05             Cell         NaN  not checked
# 3872  H23.26.404.11.74.01.06             Cell         NaN  not checked
#
#                                    link_slice_specimen   \
# 0     =HYPERLINK("http://lims2/specimens?search[name...
# 1     =HYPERLINK("http://lims2/specimens?search[name...
# 2     =HYPERLINK("http://lims2/specimens?search[name...
# 3     =HYPERLINK("http://lims2/specimens?search[name...
# 4     =HYPERLINK("http://lims2/specimens?search[name...
# ...                                                 ...
# 3868  =HYPERLINK("http://lims2/specimens?search[name...
# 3869  =HYPERLINK("http://lims2/specimens?search[name...
# 3870  =HYPERLINK("http://lims2/specimens?search[name...
# 3871  =HYPERLINK("http://lims2/specimens?search[name...
# 3872  =HYPERLINK("http://lims2/specimens?search[name...
#
#       slice_histology_well     slice_biocytin_well   ...  has_biophysical   \
# 0     EPhys_160822_05_A01_H  BIOCYTIN_160830_05_A01  ...               NaN
# 1     EPhys_160822_05_A01_H  BIOCYTIN_160830_05_A01  ...               NaN
# 2     EPhys_160822_05_A01_H  BIOCYTIN_160830_05_A01  ...               NaN
# 3     EPhys_160822_05_A01_H  BIOCYTIN_160830_05_A01  ...               NaN
# 4     EPhys_170213_04_A02_H  BIOCYTIN_170221_04_A02  ...               NaN
# ...                     ...                     ...  ...               ...
# 3868  EPhys_230417_03_A01_H  BIOCYTIN_230424_03_A01  ...               NaN
# 3869  EPhys_230417_03_A01_H  BIOCYTIN_230424_03_A01  ...               NaN
# 3870  EPhys_230417_03_A01_H  BIOCYTIN_230424_03_A01  ...               NaN
# 3871  EPhys_230417_03_A01_H  BIOCYTIN_230424_03_A01  ...               NaN
# 3872  EPhys_230417_03_A01_H  BIOCYTIN_230424_03_A01  ...               NaN
#
#       has_active_dendrite                                       nwb_filename   \
# 0                      NaN  /allen/programs/celltypes/production/humancell...
# 1                      NaN  /allen/programs/celltypes/production/humancell...
# 2                      NaN  /allen/programs/celltypes/production/humancell...
# 3                      NaN  /allen/programs/celltypes/production/humancell...
# 4                      NaN  /allen/programs/celltypes/production/humancell...
# ...                    ...                                                ...
# 3868                   NaN                                                NaN
# 3869                   NaN                                                NaN
# 3870                   NaN                                                NaN
# 3871                   NaN                                                NaN
# 3872                   NaN                                                NaN
#
#                                           swc_filename   \
# 0     /allen/programs/celltypes/production/humancell...
# 1     /allen/programs/celltypes/production/humancell...
# 2     /allen/programs/celltypes/production/humancell...
# 3     /allen/programs/celltypes/production/humancell...
# 4     /allen/programs/celltypes/production/humancell...
# ...                                                 ...
# 3868                                                NaN
# 3869                                                NaN
# 3870                                                NaN
# 3871                                                NaN
# 3872                                                NaN
#
#                                        marker_filename   swc_published_at   \
# 0     /allen/programs/celltypes/production/humancell...         3020-06-11
# 1     /allen/programs/celltypes/production/humancell...         3020-06-11
# 2     /allen/programs/celltypes/production/humancell...         3020-06-11
# 3     /allen/programs/celltypes/production/humancell...         3020-06-11
# 4     /allen/programs/celltypes/production/humancell...         3020-06-11
# ...                                                 ...                ...
# 3868                                                NaN                NaN
# 3869                                                NaN                NaN
# 3870                                                NaN                NaN
# 3871                                                NaN                NaN
# 3872                                                NaN                NaN
#
#                      disease_state   \
# 0     disease categories - epilepsy
# 1     disease categories - epilepsy
# 2     disease categories - epilepsy
# 3     disease categories - epilepsy
# 4     disease categories - epilepsy
# ...                             ...
# 3868                            NaN
# 3869                            NaN
# 3870                            NaN
# 3871                            NaN
# 3872                            NaN
#
#                                               mip_link  depth_from_pia   \
# 0     =HYPERLINK("http://lims2/siv?sub_image=5785603...      553.052552
# 1     =HYPERLINK("http://lims2/siv?sub_image=5785603...      553.052552
# 2     =HYPERLINK("http://lims2/siv?sub_image=6401041...      550.043101
# 3     =HYPERLINK("http://lims2/siv?sub_image=6401041...      550.043101
# 4     =HYPERLINK("http://lims2/siv?sub_image=6053731...      247.534634
# ...                                                 ...             ...
# 3868                                                NaN             NaN
# 3869                                                NaN             NaN
# 3870                                                NaN             NaN
# 3871                                                NaN             NaN
# 3872                                                NaN             NaN
#
#      1_2_NA_objective
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3868              NaN
# 3869              NaN
# 3870              NaN
# 3871              NaN
# 3872              NaN
#
# [3873 rows x 68 columns]

# %%
df_id[df_id['cell_specimen_id '] == 1216190688]
# Out:
#          project   cell_specimen_id   \
# 3613  hIVSCC-METc         1216190688
#
#                                     link_cell_specimen   \
# 3613  =HYPERLINK("http://lims2/specimens?id=12161906...
#
#          cell_specimen_name  cell_or_cluster  hemisphere      flipped   \
# 3613  H22.26.433.11.54.01.08             Cell         NaN  not checked
#
#                                    link_slice_specimen   \
# 3613  =HYPERLINK("http://lims2/specimens?search[name...
#
#       slice_histology_well     slice_biocytin_well   ...  has_biophysical   \
# 3613  EPhys_221010_03_A02_H  BIOCYTIN_221017_03_A02  ...               NaN
#
#       has_active_dendrite  nwb_filename   swc_filename  marker_filename   \
# 3613                   NaN           NaN            NaN              NaN
#
#       swc_published_at               disease_state  mip_link  depth_from_pia   \
# 3613                NaN  disease categories - tumor       NaN             NaN
#
#      1_2_NA_objective
# 3613              NaN
#
# [1 rows x 68 columns]

# %%
df_id.columns.values
# Out:
# array(['project ', 'cell_specimen_id ', 'link_cell_specimen ',
#        'cell_specimen_name ', 'cell_or_cluster ', 'hemisphere ',
#        'flipped ', 'link_slice_specimen ', 'slice_histology_well ',
#        'slice_biocytin_well ', 'slide20x_barcode ', 'slice_specimen_id',
#        'patched_cell_container ', 'ephys_roi_result_id ',
#        'recording_date ', 'ephys_seal_gohm ', 'tcp_sop ', 'ephys_qc ',
#        'rna_amplification_set ', 'rna_amplification_qc ',
#        'ephys_published_at ', 'labtracks_id ', 'reporters ', 'drivers ',
#        'cell_reporter ', 'has_tissue_review', 'structure ',
#        'cortex_layer ', 'dendrite_type_old', 'apical_old',
#        'dendrite_type ', 'apical ', 'pin_z_coord ', 'nwb_ready ',
#        'has_nwb_download ', 'image_series_20x_id ',
#        'image_series_20x_qc ', 'psw_20x_annotations ',
#        'layer_20x_annotations ', 'image_series_20x_tags ', 'pos_in_spec',
#        'link_ims_20x ', 'check_slide ', 'ims63x_go_no_go ',
#        'ims63x_imaging_started ', 'image_series_63x_id ',
#        'image_series_63x_qc ', 'link_ims_63x ', 'has_morph_thumb ',
#        'MorphologyThumbnail ', 'HighResMorphologyThumbnail ',
#        'has_inst_thres_thumb ', 'has_sum_thumb ', 'has_glif1 ',
#        'has_glif2 ', 'has_glif3 ', 'has_glif4 ', 'has_glif5 ',
#        'has_biophysical ', 'has_active_dendrite ', 'nwb_filename ',
#        'swc_filename ', 'marker_filename ', 'swc_published_at ',
#        'disease_state ', 'mip_link ', 'depth_from_pia ',
#        '1_2_NA_objective'], dtype=object)

# %%
df2 = pd.merge(df_anno, df_id, how='inner', left_on='cell_name_label', right_on='cell_specimen_name ', sort=True)

len(df2)
# Check length of df2

# df_id.cell_specimen_name is df_anno.cell_name_label
# df_ephys.cell_name is df_id.cell_specimen_id
# Out:
# 2649

# %%
df2
# Out:
#       exp_component_name_id    exp_component_name_label  \
# 0                      1468  RS1SS-161025-01_E12-50_S63
# 1                      1468  RS1SS-161025-01_E12-50_S63
# 2                      1471  RS1SS-161025-01_E12-50_S66
# 3                      1471  RS1SS-161025-01_E12-50_S66
# 4                      1192       huPSX170327_E1-50_S15
# ...                     ...                         ...
# 2644                   2831         SM-GE5O8_S088_E1-50
# 2645                   2832         SM-GE5O8_S089_E1-50
# 2646                   2833         SM-GE5O8_S090_E1-50
# 2647                   2834         SM-GE5O8_S091_E1-50
# 2648                   2835         SM-GE5O8_S092_E1-50
#
#      exp_component_name_color  layer_id layer_label layer_color  batch_id  \
# 0                     #430F75         1                 #FF7373         1
# 1                     #430F75         1                 #FF7373         1
# 2                     #430F75         1                 #FF7373         1
# 3                     #430F75         1                 #FF7373         1
# 4                     #311165         1                 #FF7373         3
# ...                       ...       ...         ...         ...       ...
# 2644                  #942C80        79  ZZ_Missing     #FF2637       123
# 2645                  #942C80        79  ZZ_Missing     #FF2637       123
# 2646                  #942C80        79  ZZ_Missing     #FF2637       123
# 2647                  #942C80        79  ZZ_Missing     #FF2637       123
# 2648                  #942C80        79  ZZ_Missing     #FF2637       123
#
#      batch_label batch_color  cell_name_id  ... has_biophysical   \
# 0        285-813     #000004            29  ...              NaN
# 1        285-813     #000004            29  ...              NaN
# 2        285-813     #000004            32  ...              NaN
# 3        285-813     #000004            32  ...              NaN
# 4          BT024     #010107           143  ...              NaN
# ...          ...         ...           ...  ...              ...
# 2644     RSC-196     #D3436E          1827  ...              NaN
# 2645     RSC-196     #D3436E          1828  ...              NaN
# 2646     RSC-196     #D3436E          1829  ...              NaN
# 2647     RSC-196     #D3436E          1830  ...              NaN
# 2648     RSC-196     #D3436E          1831  ...              NaN
#
#      has_active_dendrite                                       nwb_filename   \
# 0                     NaN  /allen/programs/celltypes/production/humancell...
# 1                     NaN  /allen/programs/celltypes/production/humancell...
# 2                     NaN  /allen/programs/celltypes/production/humancell...
# 3                     NaN  /allen/programs/celltypes/production/humancell...
# 4                     NaN  /allen/programs/celltypes/production/humancell...
# ...                   ...                                                ...
# 2644                  NaN                                                NaN
# 2645                  NaN                                                NaN
# 2646                  NaN                                                NaN
# 2647                  NaN                                                NaN
# 2648                  NaN                                                NaN
#
#                                           swc_filename   \
# 0     /allen/programs/celltypes/production/humancell...
# 1     /allen/programs/celltypes/production/humancell...
# 2     /allen/programs/celltypes/production/humancell...
# 3     /allen/programs/celltypes/production/humancell...
# 4     /allen/programs/celltypes/production/humancell...
# ...                                                 ...
# 2644                                                NaN
# 2645  /allen/programs/celltypes/production/humancell...
# 2646                                                NaN
# 2647                                                NaN
# 2648                                                NaN
#
#                                        marker_filename   swc_published_at   \
# 0     /allen/programs/celltypes/production/humancell...         3020-06-11
# 1     /allen/programs/celltypes/production/humancell...         3020-06-11
# 2     /allen/programs/celltypes/production/humancell...         3020-06-11
# 3     /allen/programs/celltypes/production/humancell...         3020-06-11
# 4     /allen/programs/celltypes/production/humancell...         3020-06-11
# ...                                                 ...                ...
# 2644                                                NaN                NaN
# 2645  /allen/programs/celltypes/production/humancell...                NaN
# 2646                                                NaN                NaN
# 2647                                                NaN                NaN
# 2648                                                NaN                NaN
#
#                      disease_state   \
# 0     disease categories - epilepsy
# 1     disease categories - epilepsy
# 2     disease categories - epilepsy
# 3     disease categories - epilepsy
# 4     disease categories - epilepsy
# ...                             ...
# 2644  disease categories - epilepsy
# 2645  disease categories - epilepsy
# 2646  disease categories - epilepsy
# 2647  disease categories - epilepsy
# 2648  disease categories - epilepsy
#
#                                               mip_link   depth_from_pia   \
# 0     =HYPERLINK("http://lims2/siv?sub_image=5785603...       553.052552
# 1     =HYPERLINK("http://lims2/siv?sub_image=5785603...       553.052552
# 2     =HYPERLINK("http://lims2/siv?sub_image=6401041...       550.043101
# 3     =HYPERLINK("http://lims2/siv?sub_image=6401041...       550.043101
# 4     =HYPERLINK("http://lims2/siv?sub_image=6053731...       247.534634
# ...                                                 ...              ...
# 2644                                                NaN              NaN
# 2645  =HYPERLINK("http://lims2/siv?sub_image=8575909...              NaN
# 2646  =HYPERLINK("http://lims2/siv?sub_image=8576345...              NaN
# 2647  =HYPERLINK("http://lims2/siv?sub_image=8574751...              NaN
# 2648  =HYPERLINK("http://lims2/siv?sub_image=9034108...              NaN
#
#       1_2_NA_objective
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2644               NaN
# 2645  1.2 NA objective
# 2646  1.2 NA objective
# 2647  1.2 NA objective
# 2648               NaN
#
# [2649 rows x 321 columns]

# %%
#df2 = pd.merge(df_anno, df_id, how='inner', left_on='cell_name_label', right_on='cell_specimen_name ', sort=True)

anno_names = set(df_anno['cell_name_label'])
id_names = set(df_id['cell_specimen_name '])

missing = id_names-anno_names
inds_miss = [str in list(missing) for str in df_id['cell_specimen_name ']]
df_id_missing = df_id[inds_miss]
len(df_id_missing)   # 1224+2649 = 3873
df_id_missing['recording_date '][-460:] 
#from datetime import datetime
# Out:
# 3393    2022-05-17 21:00:26
# 3398    2022-05-17 20:36:58
# 3415    2022-07-07 20:36:11
# 3416    2022-07-07 22:13:30
# 3417    2022-07-07 22:55:31
#                ...
# 3868    2023-04-13 18:40:02
# 3869    2023-04-13 19:27:23
# 3870    2023-04-13 19:57:36
# 3871    2023-04-13 21:27:28
# 3872    2023-04-13 22:27:41
# Name: recording_date , Length: 460, dtype: object

# %%
plt.hist(df_id_missing.index, bins = 50)
# Out:
# (array([ 5.,  1.,  3.,  0.,  1.,  9., 10., 11., 14., 21., 18.,  6., 52.,
#         25., 27.,  5., 18., 35., 24., 21., 17.,  8.,  6., 18., 15., 24.,
#         17.,  5.,  1., 20.,  8.,  7.,  8., 10.,  0.,  9.,  9., 16., 25.,
#         71., 74., 40., 33., 28., 75., 75., 74., 75., 75., 75.]),
#  array([ 138.  ,  212.68,  287.36,  362.04,  436.72,  511.4 ,  586.08,
#          660.76,  735.44,  810.12,  884.8 ,  959.48, 1034.16, 1108.84,
#         1183.52, 1258.2 , 1332.88, 1407.56, 1482.24, 1556.92, 1631.6 ,
#         1706.28, 1780.96, 1855.64, 1930.32, 2005.  , 2079.68, 2154.36,
#         2229.04, 2303.72, 2378.4 , 2453.08, 2527.76, 2602.44, 2677.12,
#         2751.8 , 2826.48, 2901.16, 2975.84, 3050.52, 3125.2 , 3199.88,
#         3274.56, 3349.24, 3423.92, 3498.6 , 3573.28, 3647.96, 3722.64,
#         3797.32, 3872.  ]),
#  <BarContainer object of 50 artists>)

# %%
df_id_missing.to_csv('Missing_IDs.csv')

# %%
df_id_missing[0:20]

cell_specimen_name for year in anno
look at the intermediate range
# Out:
#        project   cell_specimen_id   \
# 138  hIVSCC-MET          643574616
# 179  hIVSCC-MET          652079513
# 180  hIVSCC-MET          652079547
# 181  hIVSCC-MET          652080861
# 182  hIVSCC-MET          652085118
# 271  hIVSCC-MET          672655541
# 316  hIVSCC-MET          685802046
# 321  hIVSCC-MET          686086511
# 322  hIVSCC-MET          798435919
# 491  hIVSCC-MET          721657171
# 534  hIVSCC-MET          798433330
# 535  hIVSCC-MET          798434705
# 536  hIVSCC-MET          798431527
# 537  hIVSCC-MET          798433299
# 538  hIVSCC-MET          798434687
# 573  hIVSCC-MET          732071653
# 576  hIVSCC-MET          732113330
# 580  hIVSCC-MET          732185240
# 582  hIVSCC-MET          732195961
# 604  hIVSCC-MET          798431547
#
#                                    link_cell_specimen   \
# 138  =HYPERLINK("http://lims2/specimens?id=643574616")
# 179  =HYPERLINK("http://lims2/specimens?id=652079513")
# 180  =HYPERLINK("http://lims2/specimens?id=652079547")
# 181  =HYPERLINK("http://lims2/specimens?id=652080861")
# 182  =HYPERLINK("http://lims2/specimens?id=652085118")
# 271  =HYPERLINK("http://lims2/specimens?id=672655541")
# 316  =HYPERLINK("http://lims2/specimens?id=685802046")
# 321  =HYPERLINK("http://lims2/specimens?id=686086511")
# 322  =HYPERLINK("http://lims2/specimens?id=798435919")
# 491  =HYPERLINK("http://lims2/specimens?id=721657171")
# 534  =HYPERLINK("http://lims2/specimens?id=798433330")
# 535  =HYPERLINK("http://lims2/specimens?id=798434705")
# 536  =HYPERLINK("http://lims2/specimens?id=798431527")
# 537  =HYPERLINK("http://lims2/specimens?id=798433299")
# 538  =HYPERLINK("http://lims2/specimens?id=798434687")
# 573  =HYPERLINK("http://lims2/specimens?id=732071653")
# 576  =HYPERLINK("http://lims2/specimens?id=732113330")
# 580  =HYPERLINK("http://lims2/specimens?id=732185240")
# 582  =HYPERLINK("http://lims2/specimens?id=732195961")
# 604  =HYPERLINK("http://lims2/specimens?id=798431547")
#
#         cell_specimen_name  cell_or_cluster  hemisphere      flipped   \
# 138     H17.06.013.21.08.01             Cell       right      unknown
# 179     H17.06.015.21.05.01             Cell       right  not flipped
# 180     H17.06.015.21.09.01             Cell       right      flipped
# 181     H17.06.015.21.09.02             Cell       right      flipped
# 182     H17.06.015.21.09.03             Cell       right      flipped
# 271     H18.03.004.11.14.03             Cell        left  not flipped
# 316     H18.03.008.11.04.01             Cell        left  not checked
# 321     H18.03.008.11.06.05             Cell        left      unknown
# 322     H18.03.008.11.08.01      CellCluster        left  not checked
# 491  H18.03.313.11.06.01.04             Cell       right      flipped
# 534  H18.03.314.11.04.02.01      CellCluster       right  not checked
# 535  H18.03.314.11.04.02.02      CellCluster       right  not checked
# 536     H18.03.314.11.04.03      CellCluster       right  not checked
# 537     H18.03.314.11.04.04      CellCluster       right  not checked
# 538     H18.03.314.11.04.05      CellCluster       right  not checked
# 573  H18.03.314.11.10.01.03             Cell       right      flipped
# 576  H18.03.314.11.10.01.06             Cell       right      flipped
# 580  H18.03.314.11.10.01.10             Cell       right      flipped
# 582  H18.03.314.11.10.01.12             Cell       right      flipped
# 604  H18.03.315.11.08.02.01      CellCluster       right  not checked
#
#                                   link_slice_specimen   slice_histology_well   \
# 138  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 179  =HYPERLINK("http://lims2/specimens?search[name...      HCT_171211_01_A02
# 180  =HYPERLINK("http://lims2/specimens?search[name...      HCT_171211_01_B01
# 181  =HYPERLINK("http://lims2/specimens?search[name...      HCT_171211_01_B01
# 182  =HYPERLINK("http://lims2/specimens?search[name...      HCT_171211_01_B01
# 271  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180312_03_B02_H
# 316  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 321  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180416_02_A02_H
# 322  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 491  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180716_02_C02_H
# 534  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 535  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 536  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 537  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 538  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
# 573  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180806_02_B01_H
# 576  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180806_02_B01_H
# 580  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180806_02_B01_H
# 582  =HYPERLINK("http://lims2/specimens?search[name...  EPhys_180806_02_B01_H
# 604  =HYPERLINK("http://lims2/specimens?search[name...                    NaN
#
#        slice_biocytin_well   ...  has_biophysical   has_active_dendrite   \
# 138                     NaN  ...               NaN                   NaN
# 179  BIOCYTIN_171219_10_A02  ...               NaN                   NaN
# 180  BIOCYTIN_171219_10_B01  ...               NaN                   NaN
# 181  BIOCYTIN_171219_10_B01  ...               NaN                   NaN
# 182  BIOCYTIN_171219_10_B01  ...               NaN                   NaN
# 271  BIOCYTIN_180320_03_B02  ...               NaN                   NaN
# 316                     NaN  ...               NaN                   NaN
# 321  BIOCYTIN_180424_02_A02  ...               NaN                   NaN
# 322                     NaN  ...               NaN                   NaN
# 491  BIOCYTIN_180724_02_C02  ...               NaN                   NaN
# 534                     NaN  ...               NaN                   NaN
# 535                     NaN  ...               NaN                   NaN
# 536                     NaN  ...               NaN                   NaN
# 537                     NaN  ...               NaN                   NaN
# 538                     NaN  ...               NaN                   NaN
# 573  BIOCYTIN_180814_02_B01  ...               NaN                   NaN
# 576  BIOCYTIN_180814_02_B01  ...               NaN                   NaN
# 580  BIOCYTIN_180814_02_B01  ...               NaN                   NaN
# 582  BIOCYTIN_180814_02_B01  ...               NaN                   NaN
# 604                     NaN  ...               NaN                   NaN
#
#     nwb_filename   swc_filename  marker_filename   swc_published_at   \
# 138           NaN            NaN              NaN                NaN
# 179           NaN            NaN              NaN                NaN
# 180           NaN            NaN              NaN                NaN
# 181           NaN            NaN              NaN                NaN
# 182           NaN            NaN              NaN                NaN
# 271           NaN            NaN              NaN                NaN
# 316           NaN            NaN              NaN                NaN
# 321           NaN            NaN              NaN                NaN
# 322           NaN            NaN              NaN                NaN
# 491           NaN            NaN              NaN                NaN
# 534           NaN            NaN              NaN                NaN
# 535           NaN            NaN              NaN                NaN
# 536           NaN            NaN              NaN                NaN
# 537           NaN            NaN              NaN                NaN
# 538           NaN            NaN              NaN                NaN
# 573           NaN            NaN              NaN                NaN
# 576           NaN            NaN              NaN                NaN
# 580           NaN            NaN              NaN                NaN
# 582           NaN            NaN              NaN                NaN
# 604           NaN            NaN              NaN                NaN
#
#                     disease_state   \
# 138  disease categories - epilepsy
# 179  disease categories - epilepsy
# 180  disease categories - epilepsy
# 181  disease categories - epilepsy
# 182  disease categories - epilepsy
# 271  disease categories - epilepsy
# 316  disease categories - epilepsy
# 321  disease categories - epilepsy
# 322  disease categories - epilepsy
# 491  disease categories - epilepsy
# 534  disease categories - epilepsy
# 535  disease categories - epilepsy
# 536  disease categories - epilepsy
# 537  disease categories - epilepsy
# 538  disease categories - epilepsy
# 573  disease categories - epilepsy
# 576  disease categories - epilepsy
# 580  disease categories - epilepsy
# 582  disease categories - epilepsy
# 604  disease categories - epilepsy
#
#                                              mip_link  depth_from_pia   \
# 138                                                NaN             NaN
# 179  =HYPERLINK("http://lims2/siv?sub_image=6634409...             NaN
# 180  =HYPERLINK("http://lims2/siv?sub_image=6643257...             NaN
# 181  =HYPERLINK("http://lims2/siv?sub_image=6648778...             NaN
# 182  =HYPERLINK("http://lims2/siv?sub_image=6648768...             NaN
# 271                                                NaN             NaN
# 316                                                NaN             NaN
# 321                                                NaN             NaN
# 322                                                NaN             NaN
# 491                                                NaN             NaN
# 534                                                NaN             NaN
# 535                                                NaN             NaN
# 536                                                NaN             NaN
# 537                                                NaN             NaN
# 538                                                NaN             NaN
# 573                                                NaN             NaN
# 576                                                NaN             NaN
# 580                                                NaN             NaN
# 582                                                NaN             NaN
# 604                                                NaN             NaN
#
#     1_2_NA_objective
# 138              NaN
# 179              NaN
# 180              NaN
# 181              NaN
# 182              NaN
# 271              NaN
# 316              NaN
# 321              NaN
# 322              NaN
# 491              NaN
# 534              NaN
# 535              NaN
# 536              NaN
# 537              NaN
# 538              NaN
# 573              NaN
# 576              NaN
# 580              NaN
# 582              NaN
# 604              NaN
#
# [20 rows x 68 columns]

# %%
np.unique(df2['layer_label'])
# Out:
# array(['', '1', '2', '2.5', '3', '3a', '3b', '3c', '4', '5', '6', 'CB',
#        'CBX_mo', 'CCx_5', 'CCx_6', 'HIPbCA1', 'HIPbCA2', 'HIPbCA3',
#        'HIPbDG', 'ICx_5', 'OCx1', 'OCx2', 'OCx3', 'OCx3a', 'OCx3b',
#        'OCx3c', 'OCx4', 'OCx5', 'PCx1', 'PCx2', 'PCx3', 'PCx3a', 'PCx3b',
#        'PCx3c', 'PCx4', 'PCx5', 'PCx_3', 'PCx_4', 'PCx_5', 'PCx_6',
#        'ZZ_Missing', '_2', '_3', '_4', '_5', '_6'], dtype=object)

# %%
df2['cell_name_label']
# Out:
# 0          H16.03.007.01.01.05.07
# 1          H16.03.007.01.01.05.07
# 2          H16.03.007.01.01.05.10
# 3          H16.03.007.01.01.05.10
# 4             H17.03.002.11.09.04
#                   ...
# 2644    h19.03.002.12.01.01.02.08
# 2645    h19.03.002.12.01.01.02.09
# 2646    h19.03.002.12.01.01.02.10
# 2647    h19.03.002.12.01.01.02.11
# 2648    h19.03.002.12.01.01.02.12
# Name: cell_name_label, Length: 2649, dtype: object

# %%
df3 = pd.merge(df2, df_ephys, how='inner', left_on='cell_specimen_id ', right_on='cell_name', sort=True)
len(df3)
# Out:
# 2646

# %%
# sum(df3['subclass_label']=='FAIL')
# None are FAIL
df3['subclass_label']
# Out:
# 0       IT (L2-3)
# 1       IT (L2-3)
# 2       IT (L2-3)
# 3       IT (L2-3)
# 4       IT (L2-3)
#           ...
# 2641        PVALB
# 2642        L5 ET
# 2643          L6b
# 2644        PVALB
# 2645        PVALB
# Name: subclass_label, Length: 2646, dtype: object

# %%
# sum(df3['cluster_label']=='FAIL')
# about 15% are FAIL
df3['cluster_label']
# Out:
# 0           L2-L3|a
# 1           L2-L3|a
# 2       L2-L3 or L6
# 3       L2-L3 or L6
# 4              FAIL
#            ...
# 2641     Inhibitory
# 2642           FAIL
# 2643           FAIL
# 2644         LHX6|a
# 2645     Inhibitory
# Name: cluster_label, Length: 2646, dtype: object

# %%
plt.figure(figsize=(20,5))
sns.violinplot(data=df3, x="subclass_label", y="width_rheo", hue="broad_class_label",
               split=False, inner="quart", linewidth=1)

# You can specify a palette   palette={"Glutamatergic_neuron": "g", "GABAergic_neuron": "b"}
#                        sns.violinplot(x='species', y='sepal_width', data=datasets,
#               inner="quart", linewidth=1)
# Out:
# <Axes: xlabel='subclass_label', ylabel='width_rheo'>

# %%
# Has this been QC filtered? check params
df3_filt = df3[df3['rna_amplification_pass_fail_label']=='Pass']
print(len(df3_filt))
df3_filt = df3_filt[df3_filt['percent_reads_aligned_total_label']>=50]
print(len(df3_filt))
df3_filt = df3_filt[df3_filt['genes_label']>=1000]
print(len(df3_filt))
# NOT FILTERED FOR REGION
inds = np.array([any([x in layer for x in ['4','5','6']]) and '.' not in layer for layer in df3_filt['layer_label']])
df3_filt = df3_filt[inds]
print(len(df3_filt))
# Out:
# 2230
# 2191
# 2191
# 680

# %%
plt.figure(figsize=(20,5))
sns.violinplot(data=df3_filt, x="subclass_label", y="width_rheo", hue="broad_class_label",
               split=False, inner="quart", linewidth=1)
# Out:
# <Axes: xlabel='subclass_label', ylabel='width_rheo'>

# %%
df3_filt['subclass_label'].value_counts()
# Out:
# IT (L3-5)           173
# IT (L4-6)           141
# PVALB               118
# SST                  84
# IT (L2-3)            37
# LAMP5/PAX6/Other     37
# VIP                  26
# IT (L6)              23
# L5/6 NP              22
# L6b                  13
# L5/6 CT               4
# L5 ET                 2
# Name: subclass_label, dtype: int64

# %%
# Most variable features across categories

# 1. Following gist of: http://pklab.med.harvard.edu/scw2014/subpop_tutorial.html
df_ephys_sub = df3_filt.iloc[:,340:431]
#df_ephys
feat_means = np.nanmean(df_ephys_sub, axis=0)
feat_vars = np.nanvar(df_ephys_sub, axis=0)
feat_cv = np.sqrt(feat_vars)/feat_means

plt.scatter(np.log(feat_means), np.log(feat_cv))

# np.where(feat_cv>100)    # 90
df_ephys_sub.iloc[:,90][1:20]     

# Doesn't quite work because not enough features to fit regression lines for cut off
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_67724/3030020014.py:10: RuntimeWarning: invalid value encountered in log
#   plt.scatter(np.log(feat_means), np.log(feat_cv))
# 70          NaN
# 73          NaN
# 83          NaN
# 85          NaN
# 89          NaN
# 91          NaN
# 92          NaN
# 95          NaN
# 108    0.406955
# 109    0.765777
# 111   -0.300162
# 117   -0.068830
# 126   -0.030352
# 127   -0.048920
# 130   -0.022448
# 131   -0.082771
# 133    0.012617
# 137   -0.002972
# 140    0.125475
# Name: phase_low_chirp, dtype: float64

# %%
feat_abs_means = np.nanmean(np.log(np.abs(df_ephys_sub)), axis=0)
feat_log_vars = np.nanvar(np.log(np.abs(df_ephys_sub)), axis=0)
# logging zero creates some Infs

plt.scatter(np.log(feat_abs_means), np.log(feat_log_vars))

# Least variable
np.where(np.log(feat_log_vars)< -3)

# Most variable
most_var = np.where(np.log(feat_log_vars)> 0)

df_ephys_sub.columns[most_var]
# Out:
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/pandas/core/internals/blocks.py:402: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# /Users/xiaoping.liu/anaconda3/envs/patch-seq/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1741: RuntimeWarning: invalid value encountered in subtract
#   np.subtract(arr, avg, out=arr, casting='unsafe', where=where)
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_67724/2715907442.py:5: RuntimeWarning: invalid value encountered in log
#   plt.scatter(np.log(feat_abs_means), np.log(feat_log_vars))
# Index(['fi_fit_slope', 'mean_isi_rheo', 'postap_slope_rheo', 'adapt_hero',
#        'postap_slope_hero', 'adapt_mean', 'isi_adapt_ratio',
#        'ahp_delay_ratio_5spike', 'trough_slowdeltav_rheo',
#        'first_isi_inv_rheo', 'postap_slope_ramp', 'phase_low_chirp'],
#       dtype='object')

# %%
feat_abs_means
# Out:
# array([0.98139117, 3.64942071, 7.18433893, 5.68845411, 4.70956207,
#        7.29625537, 4.3046607 , 2.0797723 ,        inf, 2.07357626,
#        4.16607228, 3.96466617, 2.08918384, 4.47821213, 5.28292859,
#        5.10670897, 3.82898163, 2.02711853, 0.52846862, 2.28565781,
#        1.0205981 , 3.54082307, 3.57900479, 7.08204333, 5.66269817,
#        4.64210007, 7.23201474, 3.97322853, 3.9240773 , 0.6900247 ,
#        3.91944043, 3.84075853, 3.26029199, 2.3202626 , 3.38883431,
#        2.7578815 , 2.7408914 ,        inf, 2.46396879, 1.02043079,
#        3.56147063, 3.57711976, 7.14516658, 5.69929108, 4.67886029,
#        7.27850811, 3.91113909, 3.90521732, 0.46345822, 2.55178308,
#        1.83235375,        inf, 2.37847883, 2.89497709,        inf,
#        2.36991732, 2.9157393 , 1.13839713, 0.11386554, 0.12454461,
#        0.10949231, 0.05594299, 0.01104187, 2.75415701, 0.02317034,
#               inf, 2.65028583, 2.52631451, 4.2840098 , 4.28730145,
#        2.56383395, 3.74985541, 0.9747625 , 3.48447514, 7.02365536,
#        5.5938911 , 4.62038492, 7.18648067, 3.96157508, 4.18951298,
#        0.86548953, 2.71629325, 4.24520229, 0.06171373, 0.14947989,
#        1.73518553, 1.23399095, 1.30378445, 0.58698344, 1.98941405,
#        3.42792228])

# %%
feat_means
# Out:
# array([ 2.81364356e+00, -3.92597597e+01,  8.35056245e-04,  3.15683058e+02,
#        -1.25406489e+02,  7.73480235e-04,  7.56696378e+01,  1.59403298e-01,
#         7.13830195e-01,  1.73920343e-01, -6.47154253e+01,  7.25531906e+01,
#         2.64767221e-01, -8.87244903e+01,  2.28513919e+02,  1.95295784e+02,
#         2.37824147e-02,  1.78046755e-01,  2.47416413e+00,  1.86295141e-01,
#         2.95306464e+00, -3.51811276e+01,  3.86687987e+01,  8.95288754e-04,
#         3.00263734e+02, -1.14905615e+02,  7.79369301e-04, -5.36573824e+01,
#        -5.11745175e+01,  2.55226318e-01, -5.09663414e+01, -4.71363604e+01,
#         7.97717942e-02,  1.40699088e+01,  4.09182067e-02,  8.09886528e-02,
#         8.36777127e-02,  2.65993719e-01,  1.07760777e-01,  2.93462091e+00,
#        -3.58892775e+01,  3.82520247e+01,  8.37636778e-04,  3.11586542e+02,
#        -1.19768500e+02,  7.41385084e-04, -5.06409879e+01, -5.03358966e+01,
#         9.30285274e-01,  1.16222929e-01,  2.10178443e-01,  7.04918330e-01,
#         1.55048501e-01,  1.01083939e-01,  2.51217380e-01,  1.12596367e-01,
#         2.41626140e+01,  6.74435024e+00,  1.12577851e+00,  8.89504353e-01,
#         9.01420654e-01,  9.48547538e-01,  9.94424194e-01,  1.08349205e-01,
#        -2.48286486e+00, -3.05091254e-01, -1.59933899e+01, -1.44466191e+01,
#         7.38499264e+01,  7.41413022e+01,  3.34678029e+01,  6.61160659e+01,
#         2.86588214e+00, -3.36653473e+01,  2.24189967e-03,  2.83607929e+02,
#        -1.13012146e+02,  2.11300092e-03, -5.30775306e+01,  8.88515595e+01,
#        -3.08345634e-02, -1.70798767e+01,  7.22384921e+01,  1.09551187e+00,
#         1.83001355e+00,  6.87732874e+00,  3.77389918e-01,  3.48645710e-01,
#         1.27599566e+00, -1.52078777e-01,  7.56843709e-04])

# %%
feat_log_vars
# Out:
# array([1.04478531e-01, 4.62818355e-02, 1.65012903e-01, 1.92707092e-01,
#        2.95757842e-01, 1.86696718e-01, 5.42553085e-02, 5.75435249e-01,
#                   nan, 6.29435146e-01, 8.04425269e-03, 5.81838653e-01,
#        1.95736298e+01, 1.52550770e-02, 2.75704703e-01, 3.08612622e-01,
#        1.88245399e-01, 6.80789890e-01, 5.41630616e-01, 1.71163306e+00,
#        1.28273188e-01, 4.40193777e-02, 2.44030158e-01, 1.31308211e-01,
#        1.02915024e-01, 1.99481883e-01, 1.58779803e-01, 1.98928778e-02,
#        2.33294655e-02, 1.43750673e+00, 2.45994974e-02, 2.78667175e-02,
#        1.81692845e+00, 8.31187754e-01, 3.88978165e-01, 5.39409190e-01,
#        5.86539334e-01,            nan, 4.52289181e-01, 1.14399744e-01,
#        4.19603368e-02, 2.10945148e-01, 1.25249842e-01, 1.04590749e-01,
#        2.17931777e-01, 1.51111771e-01, 2.92716690e-02, 2.90268597e-02,
#        1.79917320e+00, 9.64087447e-01, 8.78622491e-01,            nan,
#        7.94936735e-01, 1.60895859e+00,            nan, 3.43982912e-01,
#        6.35362717e-01, 1.30152405e+00, 8.84026987e-03, 1.67518586e-02,
#        1.23372772e-02, 6.94035054e-03, 1.19806258e-02, 1.33771832e+00,
#        2.54657926e+00,            nan, 2.94294116e-01, 3.82690438e-01,
#        4.04845695e-02, 4.41108687e-02, 1.99217183e+00, 9.61890486e-01,
#        1.93152981e-01, 8.36610614e-02, 2.29965038e-01, 1.42156486e-01,
#        2.09738623e-01, 2.66840465e-01, 2.11861865e-02, 6.06411350e-01,
#        1.28663464e+00, 2.65502328e-01, 1.03269923e-01, 2.99218648e-02,
#        7.00224018e-01, 3.40135877e-01, 4.70399738e-01, 4.78170672e-01,
#        5.59430410e-01, 5.16327596e-01, 1.34567016e+00])

# %%
import scipy.stats as stats

df_ephys_sub1 = pd.merge(df3_filt[['subclass_label', 'broad_class_label']], df_ephys_sub, left_index=True, right_index=True)

stats.f_oneway(df_ephys_sub1['tau'][df_ephys_sub1['subclass_label'] == 'PVALB'],
               df_ephys_sub1['tau'][df_ephys_sub1['subclass_label'] == 'SST'],
               df_ephys_sub1['tau'][df_ephys_sub1['subclass_label'] == 'LAMP5/PAX6/Other'],
               df_ephys_sub1['tau'][df_ephys_sub1['subclass_label'] == 'VIP'])
# Out:
# F_onewayResult(statistic=nan, pvalue=nan)

# %%
# Subset to only inhibitory neurons
df_ephys_sub_I = df_ephys_sub1[df_ephys_sub1['broad_class_label']== 'GABAergic neuron']

np2_vec = np.empty([2, df_ephys_sub_I.shape[1]-2])

i = 0 
for feat in df_ephys_sub_I.columns[2:]:    
    aov = pg.anova(dv=feat, between='subclass_label', data=df_ephys_sub_I,
                detailed=True)
    np2_vec[0,i] = aov.np2[0].round(3)
    np2_vec[1,i] = aov['p-unc'][0]
    i+=1

data_tuples = list(zip(df_ephys_sub_I.columns[2:],np2_vec[0,:],np2_vec[1,:]))
df_I = pd.DataFrame(data_tuples)
df_I.columns = ['Feature', 'Partial_eta_squared', 'p-value']

df_I = df_I.sort_values(by='Partial_eta_squared', ascending=True)
#df_I.columns = df_ephys_sub_I.columns[2:]

min_ind = np.min(np.where(df_I['p-value']<0.05))
print(min_ind)
df_I
# Out:
# 24
#                    Feature  Partial_eta_squared       p-value
# 52           sag_tau_depol                0.001  9.933022e-01
# 21        threshold_v_rheo                0.004  8.152417e-01
# 74              width_ramp                0.004  8.045829e-01
# 77  width_suprathresh_ramp                0.004  8.034984e-01
# 11              rheobase_i                0.007  6.441265e-01
# ..                     ...                  ...           ...
# 25         downstroke_rheo                0.246  5.191114e-15
# 42              width_hero                0.246  5.090569e-15
# 44         downstroke_hero                0.285  8.518117e-18
# 85          3db_freq_chirp                0.336  1.692579e-08
# 16                     tau                0.350  6.903240e-23
#
# [91 rows x 3 columns]

# %%
# Subset to only excitatory neurons
df_ephys_sub_E = df_ephys_sub1[df_ephys_sub1['broad_class_label']== 'Glutamatergic neuron']

np2_vec = np.empty([2, df_ephys_sub_E.shape[1]-2])

i = 0 
for feat in df_ephys_sub_E.columns[2:]:    
    aov = pg.anova(dv=feat, between='subclass_label', data=df_ephys_sub_E,
                detailed=True)
    np2_vec[0,i] = aov.np2[0].round(3)
    np2_vec[1,i] = aov['p-unc'][0]
    i+=1

data_tuples = list(zip(df_ephys_sub_E.columns[2:],np2_vec[0,:],np2_vec[1,:]))
df_E = pd.DataFrame(data_tuples)
df_E.columns = ['Feature', 'Partial_eta_squared', 'p-value']

df_E = df_E.sort_values(by='Partial_eta_squared', ascending=True)

min_ind = np.min(np.where(df_E['p-value']<0.05))
print(min_ind)
df_E
# Out:
# 20
#                                    Feature  Partial_eta_squared       p-value
# 0   upstroke_downstroke_ratio_short_square                0.002  9.972244e-01
# 5           width_suprathresh_short_square                0.012  6.657666e-01
# 39          upstroke_downstroke_ratio_hero                0.012  6.917582e-01
# 52                           sag_tau_depol                0.013  8.565383e-01
# 82                        peak_deltav_ramp                0.016  3.822574e-01
# ..                                     ...                  ...           ...
# 14                        input_resistance                0.268  5.210340e-24
# 79                        threshold_i_ramp                0.297  3.979432e-28
# 13                              vm_for_sag                0.324  1.039241e-30
# 71                      first_isi_inv_hero                0.392  1.180534e-38
# 11                              rheobase_i                0.463  2.898471e-50
#
# [91 rows x 3 columns]

# %%
fig, axs = plt.subplots(2, 1, figsize=(18, 12), sharey=True)
axs[0].bar(df_E['Feature'][-24:], df_E['Partial_eta_squared'][-24:])
axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation = 90, fontsize = 16)
axs[0].set_ylabel('Effect Size')
axs[0].set_title('Features varying between cortical Exc cell types', fontsize = 22)

axs[1].bar(df_I['Feature'][-24:], df_I['Partial_eta_squared'][-24:])
axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation = 90, fontsize = 16)
axs[1].set_ylabel('Effect Size')
axs[1].set_title('Features varying between cortical Inh cell types', fontsize = 22)

fig.tight_layout()
# Out:
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_67724/3148909263.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0].set_xticklabels(axs[0].get_xticklabels(), rotation = 90, fontsize = 16)
# /var/folders/vj/7bfz8tc91053qf1swtym13nc0000gp/T/ipykernel_67724/3148909263.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[1].set_xticklabels(axs[1].get_xticklabels(), rotation = 90, fontsize = 16)

# %%
fig2, axs = plt.subplots(1, 3, figsize=(18, 6))
plt.axes(axs[0])
sns.violinplot(data=df_ephys_sub_E, x="subclass_label", y="rheobase_i",
               split=False, inner="quart", linewidth=1)
plt.title('rheobase_i')

plt.axes(axs[1])
sns.violinplot(data=df_ephys_sub_E, x="subclass_label", y="first_isi_inv_hero",
               split=False, inner="quart", linewidth=1)
plt.title('first_isi_inv_hero')

plt.axes(axs[2])
sns.violinplot(data=df_ephys_sub_E, x="subclass_label", y="vm_for_sag",
               split=False, inner="quart", linewidth=1)
plt.title('vm_for_sag')
# Out:
# Text(0.5, 1.0, 'vm_for_sag')

# %%
fig3, axs = plt.subplots(1, 3, figsize=(18, 6))
plt.axes(axs[0])
sns.violinplot(data=df_ephys_sub_I, x="subclass_label", y="tau",
               split=False, inner="quart", linewidth=1)
plt.title('tau')

plt.axes(axs[1])
sns.violinplot(data=df_ephys_sub_I, x="subclass_label", y="3db_freq_chirp",
               split=False, inner="quart", linewidth=1)
plt.title('3db_freq_chirp')

plt.axes(axs[2])
sns.violinplot(data=df_ephys_sub_I, x="subclass_label", y="downstroke_hero",
               split=False, inner="quart", linewidth=1)
plt.title('downstroke_hero')
# Out:
# Text(0.5, 1.0, 'downstroke_hero')

# %%
df_ephys_sub = df3_filt.iloc[:,340:431]
np.mean(df_ephys, axis=0)
# Out:
# upstroke_downstroke_ratio_short_square      2.813644
# threshold_v_short_square                  -39.259760
# width_short_square                          0.000835
# upstroke_short_square                     315.683058
# downstroke_short_square                  -125.406489
#                                              ...
# peak_impedance_chirp                        0.377390
# low_freq_impedance_chirp                    0.348646
# sync_freq_chirp                             1.275996
# phase_peak_chirp                           -0.152079
# phase_low_chirp                             0.000757
# Length: 91, dtype: float64

# %%
df3_filt.columns.get_loc('upstroke_downstroke_ratio_short_square')
# Out:
# 340

# %%
df3_filt.columns.get_loc('threshold_v_short_square')
# Out:
# 341

# %%
df3_ephys['threshold_v_short_square']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 df3_ephys['threshold_v_short_square']
#
# NameError: name 'df3_ephys' is not defined

# %%
df3_filt.columns.get_loc('total_inductive_phase_chirp')
# Out:
# 431

# %%
# post feature selection make a UMAP showing gene expression versus cluster

# %%
import numpy as np
np.unique(df_anno['layer_label'])
# Out:
# array(['', '1', '2', '2.5', '3', '3a', '3b', '3c', '4', '5', '6', '6a',
#        'CB', 'CBNA', 'CBX_mo', 'CCx_5', 'CCx_6', 'CTXspCA', 'HIPCA1',
#        'HIPbCA1', 'HIPbCA2', 'HIPbCA3', 'HIPbDG', 'HIPb_CA1', 'HIPb_CA2',
#        'HIPb_CA3', 'HIPb_DG', 'HYSTN', 'ICx_5', 'MOp2', 'MOp2-3',
#        'MOp2.5', 'MOp3', 'MOp5', 'MOp6a', 'MOs2-3', 'MOs5', 'OCx1',
#        'OCx2', 'OCx3', 'OCx3a', 'OCx3b', 'OCx3c', 'OCx4', 'OCx5', 'PAGPi',
#        'PCx1', 'PCx2', 'PCx3', 'PCx3a', 'PCx3b', 'PCx3c', 'PCx4', 'PCx5',
#        'PCx6', 'PCx_3', 'PCx_4', 'PCx_5', 'PCx_6', 'STRd', 'STRdCP',
#        'STRdCa', 'STRdPu', 'STRd_Ca', 'STRd_Pu', 'STRvACB', 'STRv_ACB',
#        'TEa1', 'TEa2-3', 'TEa5', 'Tcx', 'ZZ_Missing', '_2', '_3', '_4',
#        '_5', '_6', 'dGNShell', 'dlPFC3'], dtype=object)

# %%
np.unique(df3['layer_label'])
# Out:
# array(['', '1', '2', '2.5', '3', '3a', '3b', '3c', '4', '5', '6', 'CB',
#        'CBX_mo', 'CCx_5', 'CCx_6', 'HIPbCA1', 'HIPbCA2', 'HIPbCA3',
#        'HIPbDG', 'ICx_5', 'OCx1', 'OCx2', 'OCx3', 'OCx3a', 'OCx3b',
#        'OCx3c', 'OCx4', 'OCx5', 'PCx1', 'PCx2', 'PCx3', 'PCx3a', 'PCx3b',
#        'PCx3c', 'PCx4', 'PCx5', 'PCx_3', 'PCx_4', 'PCx_5', 'PCx_6',
#        'ZZ_Missing', '_2', '_3', '_4', '_5', '_6'], dtype=object)

# %%
# POST QC
df3_filt = df3_filt[df3_filt['']>=0.6]
print(len(df3_filt))

# %%
plt.hist(df3['quality_score_label'])
# Out:
# (array([301., 203., 226., 282., 328., 411., 428., 332., 122.,  13.]),
#  array([0.        , 0.06859322, 0.13718645, 0.20577967, 0.27437289,
#         0.34296611, 0.41155934, 0.48015256, 0.54874578, 0.61733901,
#         0.68593223]),
#  <BarContainer object of 10 artists>)
